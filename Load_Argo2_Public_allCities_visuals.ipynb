# %% [markdown]
# ## Install the package dependencies before running this notebook

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import os, os.path 
import numpy 
import pickle
from glob import glob

s = """
    number of trajectories in each city 
    # austin --  train: 43041 test: 6325
    # miami -- train: 55029 test:7971
    # pittsburgh -- train: 43544 test: 6361
    # dearborn -- train: 24465 test: 3671
    # washington-dc -- train: 25744 test: 3829
    # palo-alto -- train:  11993 test:1686

    trajectories sampled at 10HZ rate, input 5 seconds, output 6 seconds
    """
print(s)
# Out:
# <style>.container { width:100% !important; }</style>
#     number of trajectories in each city
#     # austin --  train: 43041 test: 6325
#     # miami -- train: 55029 test:7971
#     # pittsburgh -- train: 43544 test: 6361
#     # dearborn -- train: 24465 test: 3671
#     # washington-dc -- train: 25744 test: 3829
#     # palo-alto -- train:  11993 test:1686
#
#     trajectories sampled at 10HZ rate, input 5 seconds, output 6 seconds

# %% [markdown]
# ## Create a Torch.Dataset class for the training dataset

# %%
from glob import glob
import pickle
import numpy as np

ROOT_PATH = "./"

cities = ["austin", "miami", "pittsburgh", "dearborn", "washington-dc", "palo-alto"]
splits = ["train", "test"]

# Returns entire dataset for a city. Training input and label output, or just test input.
def get_city_trajectories(city="palo-alto", split="train", normalized=False):
    f_in = os.path.join(ROOT_PATH, split, f"{city}_inputs")
    inputs = pickle.load(open(f_in, "rb"))
    inputs = np.asarray(inputs) # All input trajectories
    outputs = None # Labels when training, empty if testing
    
    if split=="train":
        f_out = os.path.join(ROOT_PATH, split, f"{city}_outputs")
        outputs = pickle.load(open(f_out, "rb"))
        outputs = np.asarray(outputs)

    return inputs, outputs

"""Dataset class for Argoverse"""
class ArgoverseDataset(Dataset):
    def __init__(self, city:str, split:str, transform=None):
        super(ArgoverseDataset, self).__init__()
        self.transform = transform
        self.inputs, self.outputs = get_city_trajectories(city=city, split=split, normalized=False)
    def __len__(self):
        return len(self.inputs)
    def __getitem__(self, idx):
        data = (self.inputs[idx], self.outputs[idx]) # Each data is a tuple of (input trajectory, output trajectory)
        if self.transform:
            data = self.transform(data)
        return data

# %% [markdown]
# ## Checking loss graphs

# %%
# !pwd
# str = "why is pickle broken?"
# with open("pickle", "wb") as f:
#     print("dumping")
#     pickle.dump(str,f)
#     f.close()
#     print("dumped?")
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker    
with open("mlp5", "rb") as g:
    print("loading mlp5")
    data_dict = pickle.load(g)
    
    for city_number,city in enumerate(cities):
        all_losses1 = data_dict[f"train_losses_{city}"]
        all_losses2 = data_dict[f"validation_losses_{city}"]  
#         data_dict[""]
        plt.figure()
        ax = plt.gca()
        ax.set_ylim([0,500000])
        plt.title(city)
        plt.plot(all_losses1,label="avg. train loss")
        plt.plot(all_losses2,label="avg. validation loss")
        leg = plt.legend(loc='upper center')
        plt.show()
#     print(f"newstr = {newstr}")
#     g.close()
#         model = data_cit[f"model_{city}"]
        
print(type(data_dict))
# Out:
# loading mlp5
# <class 'dict'>

# %% [markdown]
# ## Inference on test set

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker   
# Inference for every city's test inputs
format_str = "ID,v0,v1,v2,v3,v4,v5,v6,v7,v8,v9,v10,v11,v12,v13,v14,v15,v16,v17,v18,v19,v20,v21,v22,v23,v24,v25,v26,v27,v28,v29,v30,v31,v32,v33,v34,v35,v36,v37,v38,v39,v40,v41,v42,v43,v44,v45,v46,v47,v48,v49,v50,v51,v52,v53,v54,v55,v56,v57,v58,v59,v60,v61,v62,v63,v64,v65,v66,v67,v68,v69,v70,v71,v72,v73,v74,v75,v76,v77,v78,v79,v80,v81,v82,v83,v84,v85,v86,v87,v88,v89,v90,v91,v92,v93,v94,v95,v96,v97,v98,v99,v100,v101,v102,v103,v104,v105,v106,v107,v108,v109,v110,v111,v112,v113,v114,v115,v116,v117,v118,v119"
with open('predictions_null.txt', 'w') as f:
    print(format_str,end='',file=f)
    for city_number,city in enumerate(cities):
        print(f"Starting testing for {city}.")

        # Prepare inputs
        true_city = 'palo-alto'
        test_inputs, groundtruths = get_city_trajectories(city=true_city, split='train', normalized=False)
        print(f"test_inputs.shape = {test_inputs.shape}")
        num_scenes = test_inputs.shape[0]

        # Setup the model
        model, model_state_dict = data_dict[f"model_{true_city}"]
        model.cuda()
        model.eval()

        # Pass all inputs through model
        for i,input_scene in enumerate(test_inputs):
#             input_scene = input_scene.cuda()
            if i!=3:
                continue
            input_scene = torch.from_numpy(input_scene).unsqueeze(0).float().cuda() # Convert to tensor+float, move to GPU
            output_scene = model(input_scene)
            truth = groundtruths[i]
            print(f"truth shape = {truth.shape}")
#             print(f"input_scene shape = {input_scene.shape}")
#             print(f"output_scene shape = {output_scene.shape}")
            input_scene = torch.squeeze(input_scene, 0)
            output_scene = torch.squeeze(output_scene, 0)
#             print(f"input_scene shape = {input_scene.shape}")
#             print(f"output_scene shape = {output_scene.shape}")            
            input_scene, output_scene = input_scene.cpu(), output_scene.cpu()
            input_scene, output_scene = input_scene.detach().numpy(), output_scene.detach().numpy()
#             print(f"input_scene shape = {input_scene.shape}")
#             print(f"output_scene shape = {output_scene.shape}")               
#             output_scene = torch.squeeze(output_scene)
            plt.figure()
            ax = plt.gca()
#             ax.set_ylim([0,500000])
#             plt.title(city)
            plt.title(true_city)
            plt.scatter(input_scene[:,0], input_scene[:,1], c='lightskyblue', label='input')
            plt.scatter(output_scene[:,0], output_scene[:,1], c='lightcoral', label='output')
            plt.scatter(truth[:,0], truth[:,1], c='g', label='ground truth')
#             plt.plot(input_scene,label="input")
#             plt.plot(output_scene,label="output")
            leg = plt.legend(loc='upper center')
            plt.show()
            if i==1000:
                break
# #             print(f"output_scene.shape = {output_scene.shape}")
#             # Process output into submission format
#             output_str = f"\n{i}_{city}" # Ex. 0_austin
#             for j,coord_pair in enumerate(output_scene):
#                 x,y = coord_pair
#                 output_str += f",{x},{y}"
#             # Print to file
#             print(output_str,end='',file=f)
# #             break
# #         break
        
    
    
    # Process model outputs
# Out:
# Starting testing for austin.
# test_inputs.shape = (11993, 50, 2)
# truth shape = (60, 2)
# Starting testing for miami.
# test_inputs.shape = (11993, 50, 2)
# truth shape = (60, 2)
# Starting testing for pittsburgh.
# test_inputs.shape = (11993, 50, 2)
# truth shape = (60, 2)
# Starting testing for dearborn.
# test_inputs.shape = (11993, 50, 2)
# truth shape = (60, 2)
# Starting testing for washington-dc.
# test_inputs.shape = (11993, 50, 2)
# truth shape = (60, 2)
# Starting testing for palo-alto.
# test_inputs.shape = (11993, 50, 2)
# truth shape = (60, 2)

# %% [markdown]
# ## Loop over all cities

# %%
import time
from tqdm import tqdm

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

data_dict = {}

# Set hyperparameters
batch_size = 64
lr = 0.0003
num_epochs = 250
data_dict["batch_size"] = batch_size
data_dict["lr"] = lr
data_dict["num_epochs"] = num_epochs

# Train one model per city
models = [ None for city in cities ]
for city_number,city in enumerate(cities):
    print(f"Starting training for {city}.")
    # Prepare Dataset and Dataloader
    full_dataset  = ArgoverseDataset(city = city, split = 'train')
    train_set, validation_set = torch.utils.data.random_split(full_dataset, [int(len(full_dataset)*99/100), len(full_dataset)-int(len(full_dataset)*99/100)])
    train_loader = DataLoader(train_set, batch_size=batch_size,shuffle=True,drop_last=True,pin_memory=True)
    validation_loader = DataLoader(validation_set, batch_size=batch_size,drop_last=True)
    train_samples_per_epoch = len(train_loader) * batch_size # Number of batches times batch size
    validation_samples_per_epoch = len(validation_loader) * batch_size
    print(f"train_samples_per_epoch = {train_samples_per_epoch}")
    print(f"validation_samples_per_epoch = {validation_samples_per_epoch}")
    
    # Create model/optim/loss
    model = nn.Sequential(nn.Flatten(1,2),
                    nn.Linear(100, 1024),
                    nn.ReLU(),
                    nn.Linear(1024, 1024),
                    nn.ReLU(),
                    nn.Linear(1024,120),
                    nn.Unflatten(1,(60,2)))
    model.cuda()
    opt = torch.optim.Adam(model.parameters(),lr=lr)
    # https://pytorch.org/docs/stable/optim.html#torch.optim.lr_scheduler.ReduceLROnPlateau
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, 'min')
    loss_func = nn.MSELoss(reduction='sum')
    
    # Train model
    all_losses1 = []
    all_losses2 = []
    start_time = time.time()
    for epoch in range(num_epochs):
        # Train set
        model.train()
        train_loss = 0
        train_loss_alt = 0
        for i_batch, sample_batch in enumerate(train_loader):
            # Get input and output labels
            inp, out = sample_batch 
            inp = inp.float()
            out = out.float()      
            inp, out = inp.cuda(), out.cuda()
            # Forward pass
            out_hats = model(inp)
            l = loss_func(out_hats, out)     
            # Gradient descent
            opt.zero_grad()
            l.backward()
            opt.step()        
            train_loss += l.item()
        all_losses1.append(train_loss / train_samples_per_epoch)  # Loss per training sample
        
        
        # Validation set
        model.eval()
        validation_loss = 0
        validation_loss_alt = 0
        for i_batch, sample_batch in enumerate(validation_loader):
            inp, out = sample_batch
            inp = inp.float()
            out = out.float()
            inp, out = inp.cuda(), out.cuda()
            # Forward pass
            l = loss_func(model(inp), out)
            validation_loss += l.item()
        scheduler.step(train_loss)
        all_losses2.append(validation_loss / validation_samples_per_epoch) # Loss per validation sample

        # Print training progress
        print(f'(train) epoch {epoch + 1},      avg. train loss     : {train_loss / train_samples_per_epoch}')
        print(f'(validation) epoch {epoch + 1}, avg. validation loss: {validation_loss / validation_samples_per_epoch}')
        
    end_time = time.time()
    print(f"Entire training of {city}'s model took {end_time-start_time} seconds.")    
    models[city_number] = model
    data_dict[f"model_{city}"] = (model, model.state_dict())
    data_dict[f"train_losses_{city}"]  = all_losses1
    data_dict[f"validation_losses_{city}"]  = all_losses2

    # Graph training progress, should be per trajectory loss
    plt.figure()
    ax = plt.gca()
    ax.set_ylim([0,500000])
    plt.plot(all_losses1,label="avg. train loss")
    plt.plot(all_losses2,label="avg. validation loss")
    leg = plt.legend(loc='upper center')
    plt.show()    
    print()
    print()
data_dict["models"] = models    
# data_dir = os.path.join("/home/mhsiu/argo_kaggle/checkpoints/mlp1")
# print(data_dir)
with open("mlp5", "wb") as f:
    print("dumping")
    pickle.dump(data_dict,f)
    f.close()
    print("dumped?")
    
# with open("mlp1", "rb") as f:
#     print("loading")
#     loaded = pickle.load(f)
#     newstr = loaded["num_epochs"]
#     print(f"loaded = {newstr}")
#     f.close()
# #     print("dumped?")
# Out:
# Starting training for austin.
# train_samples_per_epoch = 42560
# validation_samples_per_epoch = 384
# (train) epoch 1,      avg. train loss     : 2333699.9161654133
# (validation) epoch 1, avg. validation loss: 97178.2109375
# (train) epoch 2,      avg. train loss     : 113919.08498590226
# (validation) epoch 2, avg. validation loss: 99770.77734375
# (train) epoch 3,      avg. train loss     : 99645.3463287124
# (validation) epoch 3, avg. validation loss: 76012.73828125
# (train) epoch 4,      avg. train loss     : 77956.10279017857
# (validation) epoch 4, avg. validation loss: 37843.937174479164
# (train) epoch 5,      avg. train loss     : 74317.27010984492
# (validation) epoch 5, avg. validation loss: 59581.924479166664
# (train) epoch 6,      avg. train loss     : 62725.1629199953
# (validation) epoch 6, avg. validation loss: 23329.095703125
# (train) epoch 7,      avg. train loss     : 53253.81322544643
# (validation) epoch 7, avg. validation loss: 25230.847005208332
# (train) epoch 8,      avg. train loss     : 50589.59460467575
# (validation) epoch 8, avg. validation loss: 27238.278645833332
# (train) epoch 9,      avg. train loss     : 47489.81569548872
# (validation) epoch 9, avg. validation loss: 34682.937825520836
# (train) epoch 10,      avg. train loss     : 42312.53028959117
# (validation) epoch 10, avg. validation loss: 19337.219075520832
# (train) epoch 11,      avg. train loss     : 50019.09244742716
# (validation) epoch 11, avg. validation loss: 23852.006510416668
# (train) epoch 12,      avg. train loss     : 70283.89627290884
# (validation) epoch 12, avg. validation loss: 18936.413736979168
# (train) epoch 13,      avg. train loss     : 34308.14385867011
# (validation) epoch 13, avg. validation loss: 44957.472005208336
# (train) epoch 14,      avg. train loss     : 38544.63591694079
# (validation) epoch 14, avg. validation loss: 25471.006184895832
# (train) epoch 15,      avg. train loss     : 57619.15153753525
# (validation) epoch 15, avg. validation loss: 21296.599934895832
# (train) epoch 16,      avg. train loss     : 29035.575073425753
# (validation) epoch 16, avg. validation loss: 25290.288736979168
# (train) epoch 17,      avg. train loss     : 37487.7793747063
# (validation) epoch 17, avg. validation loss: 19647.221028645832
# (train) epoch 18,      avg. train loss     : 30430.36175693139
# (validation) epoch 18, avg. validation loss: 24053.33984375
# (train) epoch 19,      avg. train loss     : 35601.357493832234
# (validation) epoch 19, avg. validation loss: 99429.95703125
# (train) epoch 20,      avg. train loss     : 30783.24677367246
# (validation) epoch 20, avg. validation loss: 36565.980143229164
# (train) epoch 21,      avg. train loss     : 31017.371541647088
# (validation) epoch 21, avg. validation loss: 28635.368815104168
# (train) epoch 22,      avg. train loss     : 29351.595766271148
# (validation) epoch 22, avg. validation loss: 33356.952799479164
# (train) epoch 23,      avg. train loss     : 35120.57095864662
# (validation) epoch 23, avg. validation loss: 15155.187662760416
# (train) epoch 24,      avg. train loss     : 30540.70413974389
# (validation) epoch 24, avg. validation loss: 21593.023763020832
# (train) epoch 25,      avg. train loss     : 28493.193719161183
# (validation) epoch 25, avg. validation loss: 41120.009114583336
# (train) epoch 26,      avg. train loss     : 30607.303478912123
# (validation) epoch 26, avg. validation loss: 48099.445963541664
# (train) epoch 27,      avg. train loss     : 30412.926583059212
# (validation) epoch 27, avg. validation loss: 16498.057942708332
# (train) epoch 28,      avg. train loss     : 24868.309148848683
# (validation) epoch 28, avg. validation loss: 19054.293619791668
# (train) epoch 29,      avg. train loss     : 41503.67087494126
# (validation) epoch 29, avg. validation loss: 22298.874348958332
# (train) epoch 30,      avg. train loss     : 24893.44095101034
# (validation) epoch 30, avg. validation loss: 17178.766276041668
# (train) epoch 31,      avg. train loss     : 27123.01420200893
# (validation) epoch 31, avg. validation loss: 37547.132161458336
# (train) epoch 32,      avg. train loss     : 26991.55675957472
# (validation) epoch 32, avg. validation loss: 44714.632161458336
# (train) epoch 33,      avg. train loss     : 26119.199960350095
# (validation) epoch 33, avg. validation loss: 25679.830729166668
# (train) epoch 34,      avg. train loss     : 27494.887966987782
# (validation) epoch 34, avg. validation loss: 24399.588541666668
# (train) epoch 35,      avg. train loss     : 23635.968260984493
# (validation) epoch 35, avg. validation loss: 28375.750651041668
# (train) epoch 36,      avg. train loss     : 28401.153593456296
# (validation) epoch 36, avg. validation loss: 30589.8271484375
# (train) epoch 37,      avg. train loss     : 26297.794544466637
# (validation) epoch 37, avg. validation loss: 17759.549641927082
# (train) epoch 38,      avg. train loss     : 25589.799246651786
# (validation) epoch 38, avg. validation loss: 48987.829427083336
# (train) epoch 39,      avg. train loss     : 29407.011516094924
# (validation) epoch 39, avg. validation loss: 16747.75
# (train) epoch 40,      avg. train loss     : 22193.847748766446
# (validation) epoch 40, avg. validation loss: 21510.7158203125
# (train) epoch 41,      avg. train loss     : 25247.3240821781
# (validation) epoch 41, avg. validation loss: 16441.3876953125
# (train) epoch 42,      avg. train loss     : 23991.729496593045
# (validation) epoch 42, avg. validation loss: 27677.794270833332
# (train) epoch 43,      avg. train loss     : 25365.27599124765
# (validation) epoch 43, avg. validation loss: 20375.65625
# (train) epoch 44,      avg. train loss     : 22979.18908893327
# (validation) epoch 44, avg. validation loss: 19261.068684895832
# (train) epoch 45,      avg. train loss     : 23878.61481144267
# (validation) epoch 45, avg. validation loss: 22527.1171875
# (train) epoch 46,      avg. train loss     : 24091.867102326127
# (validation) epoch 46, avg. validation loss: 47616.041015625
# (train) epoch 47,      avg. train loss     : 24262.130644971803
# (validation) epoch 47, avg. validation loss: 21792.775716145832
# (train) epoch 48,      avg. train loss     : 24745.13059063675
# (validation) epoch 48, avg. validation loss: 34279.403971354164
# (train) epoch 49,      avg. train loss     : 23280.01064379699
# (validation) epoch 49, avg. validation loss: 26871.157877604168
# (train) epoch 50,      avg. train loss     : 24945.141567786653
# (validation) epoch 50, avg. validation loss: 15463.30224609375
# (train) epoch 51,      avg. train loss     : 24515.82850387688
# (validation) epoch 51, avg. validation loss: 20184.277669270832
# (train) epoch 52,      avg. train loss     : 12001.229991482613
# (validation) epoch 52, avg. validation loss: 12277.056803385416
# (train) epoch 53,      avg. train loss     : 11857.211966194784
# (validation) epoch 53, avg. validation loss: 12423.371419270834
# (train) epoch 54,      avg. train loss     : 11906.452616893797
# (validation) epoch 54, avg. validation loss: 12183.39501953125
# (train) epoch 55,      avg. train loss     : 11994.472902960526
# (validation) epoch 55, avg. validation loss: 12291.058430989584
# (train) epoch 56,      avg. train loss     : 12123.069225064615
# (validation) epoch 56, avg. validation loss: 13393.584309895834
# (train) epoch 57,      avg. train loss     : 11944.671537241542
# (validation) epoch 57, avg. validation loss: 12018.904296875
# (train) epoch 58,      avg. train loss     : 11955.454529634633
# (validation) epoch 58, avg. validation loss: 12376.80126953125
# (train) epoch 59,      avg. train loss     : 11852.762533775845
# (validation) epoch 59, avg. validation loss: 16640.38330078125
# (train) epoch 60,      avg. train loss     : 11947.633782454182
# (validation) epoch 60, avg. validation loss: 12752.384928385416
# (train) epoch 61,      avg. train loss     : 11983.557671522556
# (validation) epoch 61, avg. validation loss: 11622.176920572916
# (train) epoch 62,      avg. train loss     : 11822.512385455828
# (validation) epoch 62, avg. validation loss: 12442.199869791666
# (train) epoch 63,      avg. train loss     : 11719.709793526787
# (validation) epoch 63, avg. validation loss: 11914.852213541666
# (train) epoch 64,      avg. train loss     : 11583.375520588581
# (validation) epoch 64, avg. validation loss: 11844.178059895834
# (train) epoch 65,      avg. train loss     : 11449.650146117247
# (validation) epoch 65, avg. validation loss: 11240.517740885416
# (train) epoch 66,      avg. train loss     : 11440.080432037124
# (validation) epoch 66, avg. validation loss: 12354.510904947916
# (train) epoch 67,      avg. train loss     : 11634.088175516918
# (validation) epoch 67, avg. validation loss: 10890.646484375
# (train) epoch 68,      avg. train loss     : 11062.606645030544
# (validation) epoch 68, avg. validation loss: 12035.16162109375
# (train) epoch 69,      avg. train loss     : 11173.891456913769
# (validation) epoch 69, avg. validation loss: 11101.154134114584
# (train) epoch 70,      avg. train loss     : 11134.746496857379
# (validation) epoch 70, avg. validation loss: 11041.002766927084
# (train) epoch 71,      avg. train loss     : 11203.997504258694
# (validation) epoch 71, avg. validation loss: 12297.85888671875
# (train) epoch 72,      avg. train loss     : 11032.333721510808
# (validation) epoch 72, avg. validation loss: 16180.949055989584
# (train) epoch 73,      avg. train loss     : 10800.074130639097
# (validation) epoch 73, avg. validation loss: 10744.857747395834
# (train) epoch 74,      avg. train loss     : 10702.366034715695
# (validation) epoch 74, avg. validation loss: 12434.0244140625
# (train) epoch 75,      avg. train loss     : 10951.233305186795
# (validation) epoch 75, avg. validation loss: 11662.975748697916
# (train) epoch 76,      avg. train loss     : 10594.175245242011
# (validation) epoch 76, avg. validation loss: 10081.423990885416
# (train) epoch 77,      avg. train loss     : 10536.215951744596
# (validation) epoch 77, avg. validation loss: 10251.8994140625
# (train) epoch 78,      avg. train loss     : 10583.404807918234
# (validation) epoch 78, avg. validation loss: 12396.983072916666
# (train) epoch 79,      avg. train loss     : 10505.96248237782
# (validation) epoch 79, avg. validation loss: 9851.672607421875
# (train) epoch 80,      avg. train loss     : 10270.354007577538
# (validation) epoch 80, avg. validation loss: 10501.340983072916
# (train) epoch 81,      avg. train loss     : 10238.954339461936
# (validation) epoch 81, avg. validation loss: 10071.777425130209
# (train) epoch 82,      avg. train loss     : 10311.679816729324
# (validation) epoch 82, avg. validation loss: 9281.727213541666
# (train) epoch 83,      avg. train loss     : 10308.353801985433
# (validation) epoch 83, avg. validation loss: 13497.695638020834
# (train) epoch 84,      avg. train loss     : 10077.188484639333
# (validation) epoch 84, avg. validation loss: 9659.158772786459
# (train) epoch 85,      avg. train loss     : 10110.74725975094
# (validation) epoch 85, avg. validation loss: 10390.138346354166
# (train) epoch 86,      avg. train loss     : 9793.153880550986
# (validation) epoch 86, avg. validation loss: 9148.705240885416
# (train) epoch 87,      avg. train loss     : 10046.109468250705
# (validation) epoch 87, avg. validation loss: 10161.025065104166
# (train) epoch 88,      avg. train loss     : 9768.517852737312
# (validation) epoch 88, avg. validation loss: 9811.435709635416
# (train) epoch 89,      avg. train loss     : 9628.480630286655
# (validation) epoch 89, avg. validation loss: 10089.8994140625
# (train) epoch 90,      avg. train loss     : 9865.730043614896
# (validation) epoch 90, avg. validation loss: 10253.101236979166
# (train) epoch 91,      avg. train loss     : 9617.863441318139
# (validation) epoch 91, avg. validation loss: 8697.731119791666
# (train) epoch 92,      avg. train loss     : 9503.887645382989
# (validation) epoch 92, avg. validation loss: 8950.113444010416
# (train) epoch 93,      avg. train loss     : 9605.296687030075
# (validation) epoch 93, avg. validation loss: 9173.837239583334
# (train) epoch 94,      avg. train loss     : 9424.398853824014
# (validation) epoch 94, avg. validation loss: 9743.702962239584
# (train) epoch 95,      avg. train loss     : 9244.622286918468
# (validation) epoch 95, avg. validation loss: 9715.73876953125
# (train) epoch 96,      avg. train loss     : 9187.75411037359
# (validation) epoch 96, avg. validation loss: 10549.57275390625
# (train) epoch 97,      avg. train loss     : 9324.185272262688
# (validation) epoch 97, avg. validation loss: 8724.578206380209
# (train) epoch 98,      avg. train loss     : 9154.202115395912
# (validation) epoch 98, avg. validation loss: 9559.925130208334
# (train) epoch 99,      avg. train loss     : 9073.23576862077
# (validation) epoch 99, avg. validation loss: 8753.046793619791
# (train) epoch 100,      avg. train loss     : 9001.742654487782
# (validation) epoch 100, avg. validation loss: 8908.269368489584
# (train) epoch 101,      avg. train loss     : 9056.654481907895
# (validation) epoch 101, avg. validation loss: 9331.199381510416
# (train) epoch 102,      avg. train loss     : 8905.999309797933
# (validation) epoch 102, avg. validation loss: 9693.783854166666
# (train) epoch 103,      avg. train loss     : 9197.945430715461
# (validation) epoch 103, avg. validation loss: 9016.334798177084
# (train) epoch 104,      avg. train loss     : 9023.25039356203
# (validation) epoch 104, avg. validation loss: 8760.747721354166
# (train) epoch 105,      avg. train loss     : 8789.553734066612
# (validation) epoch 105, avg. validation loss: 8794.244954427084
# (train) epoch 106,      avg. train loss     : 8718.000447897086
# (validation) epoch 106, avg. validation loss: 8279.805013020834
# (train) epoch 107,      avg. train loss     : 8834.063229851974
# (validation) epoch 107, avg. validation loss: 9161.381510416666
# (train) epoch 108,      avg. train loss     : 8663.053840166824
# (validation) epoch 108, avg. validation loss: 8911.588053385416
# (train) epoch 109,      avg. train loss     : 8919.295085614427
# (validation) epoch 109, avg. validation loss: 9129.422932942709
# (train) epoch 110,      avg. train loss     : 8512.817102326127
# (validation) epoch 110, avg. validation loss: 11811.4306640625
# (train) epoch 111,      avg. train loss     : 8642.810784774436
# (validation) epoch 111, avg. validation loss: 8154.282552083333
# (train) epoch 112,      avg. train loss     : 8611.939405398261
# (validation) epoch 112, avg. validation loss: 8746.48486328125
# (train) epoch 113,      avg. train loss     : 8562.63935840578
# (validation) epoch 113, avg. validation loss: 7780.356363932292
# (train) epoch 114,      avg. train loss     : 8431.184664297463
# (validation) epoch 114, avg. validation loss: 7671.828125
# (train) epoch 115,      avg. train loss     : 8448.282753759398
# (validation) epoch 115, avg. validation loss: 8559.613932291666
# (train) epoch 116,      avg. train loss     : 8545.706609051927
# (validation) epoch 116, avg. validation loss: 8295.702799479166
# (train) epoch 117,      avg. train loss     : 8424.13041588346
# (validation) epoch 117, avg. validation loss: 8689.407552083334
# (train) epoch 118,      avg. train loss     : 8586.872722333177
# (validation) epoch 118, avg. validation loss: 7656.373291015625
# (train) epoch 119,      avg. train loss     : 8132.085485931626
# (validation) epoch 119, avg. validation loss: 9422.368245442709
# (train) epoch 120,      avg. train loss     : 8401.583573557918
# (validation) epoch 120, avg. validation loss: 9470.757161458334
# (train) epoch 121,      avg. train loss     : 8412.45816420935
# (validation) epoch 121, avg. validation loss: 7931.74072265625
# (train) epoch 122,      avg. train loss     : 8122.701048519737
# (validation) epoch 122, avg. validation loss: 8351.732503255209
# (train) epoch 123,      avg. train loss     : 8479.315105879934
# (validation) epoch 123, avg. validation loss: 10881.1396484375
# (train) epoch 124,      avg. train loss     : 8360.146996886748
# (validation) epoch 124, avg. validation loss: 8183.136637369792
# (train) epoch 125,      avg. train loss     : 7973.078454681626
# (validation) epoch 125, avg. validation loss: 8421.530110677084
# (train) epoch 126,      avg. train loss     : 8344.13700290766
# (validation) epoch 126, avg. validation loss: 7859.107828776042
# (train) epoch 127,      avg. train loss     : 8128.933795670818
# (validation) epoch 127, avg. validation loss: 8498.5703125
# (train) epoch 128,      avg. train loss     : 8095.958201289356
# (validation) epoch 128, avg. validation loss: 7659.034342447917
# (train) epoch 129,      avg. train loss     : 8161.709363986137
# (validation) epoch 129, avg. validation loss: 7480.700113932292
# (train) epoch 130,      avg. train loss     : 8086.119236078477
# (validation) epoch 130, avg. validation loss: 8270.121337890625
# (train) epoch 131,      avg. train loss     : 8132.803125367129
# (validation) epoch 131, avg. validation loss: 8316.328531901041
# (train) epoch 132,      avg. train loss     : 8103.325251850329
# (validation) epoch 132, avg. validation loss: 8400.802083333334
# (train) epoch 133,      avg. train loss     : 8239.006774626998
# (validation) epoch 133, avg. validation loss: 8818.40234375
# (train) epoch 134,      avg. train loss     : 7952.279199953007
# (validation) epoch 134, avg. validation loss: 8217.3203125
# (train) epoch 135,      avg. train loss     : 8257.513113839286
# (validation) epoch 135, avg. validation loss: 7151.066650390625
# (train) epoch 136,      avg. train loss     : 7966.213373766447
# (validation) epoch 136, avg. validation loss: 8003.216634114583
# (train) epoch 137,      avg. train loss     : 7833.260259413181
# (validation) epoch 137, avg. validation loss: 7906.975016276042
# (train) epoch 138,      avg. train loss     : 8124.815007856556
# (validation) epoch 138, avg. validation loss: 7792.818277994792
# (train) epoch 139,      avg. train loss     : 8036.9630161830355
# (validation) epoch 139, avg. validation loss: 8117.539713541667
# (train) epoch 140,      avg. train loss     : 7917.634606291119
# (validation) epoch 140, avg. validation loss: 8062.328450520833
# (train) epoch 141,      avg. train loss     : 8039.954985608552
# (validation) epoch 141, avg. validation loss: 7267.212890625
# (train) epoch 142,      avg. train loss     : 7904.15195018797
# (validation) epoch 142, avg. validation loss: 9199.313395182291
# (train) epoch 143,      avg. train loss     : 8083.631220629699
# (validation) epoch 143, avg. validation loss: 8074.878824869792
# (train) epoch 144,      avg. train loss     : 7982.392807213346
# (validation) epoch 144, avg. validation loss: 7984.032552083333
# (train) epoch 145,      avg. train loss     : 7842.100848801691
# (validation) epoch 145, avg. validation loss: 8663.958658854166
# (train) epoch 146,      avg. train loss     : 7996.538631490836
# (validation) epoch 146, avg. validation loss: 7937.659342447917
# (train) epoch 147,      avg. train loss     : 7595.455095012923
# (validation) epoch 147, avg. validation loss: 7830.872639973958
# (train) epoch 148,      avg. train loss     : 7759.860597538769
# (validation) epoch 148, avg. validation loss: 8028.257975260417
# (train) epoch 149,      avg. train loss     : 7744.7813572015975
# (validation) epoch 149, avg. validation loss: 8147.2373046875
# (train) epoch 150,      avg. train loss     : 7905.101146175987
# (validation) epoch 150, avg. validation loss: 7736.707926432292
# (train) epoch 151,      avg. train loss     : 7578.663383311795
# (validation) epoch 151, avg. validation loss: 7461.386474609375
# (train) epoch 152,      avg. train loss     : 8057.103357392505
# (validation) epoch 152, avg. validation loss: 7862.502522786458
# (train) epoch 153,      avg. train loss     : 7783.696963110902
# (validation) epoch 153, avg. validation loss: 9008.103678385416
# (train) epoch 154,      avg. train loss     : 7943.07303218985
# (validation) epoch 154, avg. validation loss: 7559.048583984375
# (train) epoch 155,      avg. train loss     : 7579.733101797462
# (validation) epoch 155, avg. validation loss: 6979.993977864583
# (train) epoch 156,      avg. train loss     : 7651.541562646851
# (validation) epoch 156, avg. validation loss: 6863.161946614583
# (train) epoch 157,      avg. train loss     : 7624.766965754229
# (validation) epoch 157, avg. validation loss: 6898.880289713542
# (train) epoch 158,      avg. train loss     : 7663.741804217575
# (validation) epoch 158, avg. validation loss: 7144.147705078125
# (train) epoch 159,      avg. train loss     : 7847.5451612429515
# (validation) epoch 159, avg. validation loss: 7178.139892578125
# (train) epoch 160,      avg. train loss     : 7465.318651976621
# (validation) epoch 160, avg. validation loss: 8233.798502604166
# (train) epoch 161,      avg. train loss     : 7469.313621211231
# (validation) epoch 161, avg. validation loss: 6784.695556640625
# (train) epoch 162,      avg. train loss     : 7770.379325511043
# (validation) epoch 162, avg. validation loss: 7847.177652994792
# (train) epoch 163,      avg. train loss     : 7536.761559416119
# (validation) epoch 163, avg. validation loss: 8474.518391927084
# (train) epoch 164,      avg. train loss     : 7678.504151492011
# (validation) epoch 164, avg. validation loss: 8006.784830729167
# (train) epoch 165,      avg. train loss     : 7293.360778900376
# (validation) epoch 165, avg. validation loss: 7094.058512369792
# (train) epoch 166,      avg. train loss     : 7692.003594557683
# (validation) epoch 166, avg. validation loss: 7992.966064453125
# (train) epoch 167,      avg. train loss     : 7471.276836010926
# (validation) epoch 167, avg. validation loss: 8183.015950520833
# (train) epoch 168,      avg. train loss     : 7498.029265301927
# (validation) epoch 168, avg. validation loss: 9301.695638020834
# (train) epoch 169,      avg. train loss     : 7206.774060884633
# (validation) epoch 169, avg. validation loss: 6515.243977864583
# (train) epoch 170,      avg. train loss     : 7519.11318065672
# (validation) epoch 170, avg. validation loss: 8051.117024739583
# (train) epoch 171,      avg. train loss     : 7432.995421537242
# (validation) epoch 171, avg. validation loss: 6564.448974609375
# (train) epoch 172,      avg. train loss     : 7244.354943021616
# (validation) epoch 172, avg. validation loss: 6744.887288411458
# (train) epoch 173,      avg. train loss     : 7513.056937999295
# (validation) epoch 173, avg. validation loss: 7334.357421875
# (train) epoch 174,      avg. train loss     : 7258.115413900963
# (validation) epoch 174, avg. validation loss: 8102.968505859375
# (train) epoch 175,      avg. train loss     : 7490.6020669349155
# (validation) epoch 175, avg. validation loss: 8119.28564453125
# (train) epoch 176,      avg. train loss     : 7272.163906470278
# (validation) epoch 176, avg. validation loss: 8480.49267578125
# (train) epoch 177,      avg. train loss     : 7662.774192683858
# (validation) epoch 177, avg. validation loss: 6679.378336588542
# (train) epoch 178,      avg. train loss     : 7479.56553909187
# (validation) epoch 178, avg. validation loss: 7831.745524088542
# (train) epoch 179,      avg. train loss     : 7086.236903415766
# (validation) epoch 179, avg. validation loss: 7067.219319661458
# (train) epoch 180,      avg. train loss     : 7220.17484323602
# (validation) epoch 180, avg. validation loss: 7093.387044270833
# (train) epoch 181,      avg. train loss     : 7342.087388392857
# (validation) epoch 181, avg. validation loss: 7174.069742838542
# (train) epoch 182,      avg. train loss     : 7431.428572897086
# (validation) epoch 182, avg. validation loss: 9749.14794921875
# (train) epoch 183,      avg. train loss     : 7273.582227296757
# (validation) epoch 183, avg. validation loss: 7160.64794921875
# (train) epoch 184,      avg. train loss     : 7208.507620491659
# (validation) epoch 184, avg. validation loss: 6952.37060546875
# (train) epoch 185,      avg. train loss     : 7199.0178428248355
# (validation) epoch 185, avg. validation loss: 6533.194905598958
# (train) epoch 186,      avg. train loss     : 7364.60175487547
# (validation) epoch 186, avg. validation loss: 10808.367350260416
# (train) epoch 187,      avg. train loss     : 7199.2018242628055
# (validation) epoch 187, avg. validation loss: 6765.396321614583
# (train) epoch 188,      avg. train loss     : 7564.565201333412
# (validation) epoch 188, avg. validation loss: 7337.388590494792
# (train) epoch 189,      avg. train loss     : 7142.134841987782
# (validation) epoch 189, avg. validation loss: 7426.44189453125
# (train) epoch 190,      avg. train loss     : 7251.046583499765
# (validation) epoch 190, avg. validation loss: 6200.370035807292
# (train) epoch 191,      avg. train loss     : 5627.428125367129
# (validation) epoch 191, avg. validation loss: 5788.1767578125
# (train) epoch 192,      avg. train loss     : 5539.684492481203
# (validation) epoch 192, avg. validation loss: 5702.305745442708
# (train) epoch 193,      avg. train loss     : 5543.072518576715
# (validation) epoch 193, avg. validation loss: 5613.797770182292
# (train) epoch 194,      avg. train loss     : 5552.375854308623
# (validation) epoch 194, avg. validation loss: 6038.595296223958
# (train) epoch 195,      avg. train loss     : 5532.63442823367
# (validation) epoch 195, avg. validation loss: 5662.491780598958
# (train) epoch 196,      avg. train loss     : 5504.7002955386515
# (validation) epoch 196, avg. validation loss: 5671.548502604167
# (train) epoch 197,      avg. train loss     : 5481.978448073308
# (validation) epoch 197, avg. validation loss: 5774.326171875
# (train) epoch 198,      avg. train loss     : 5478.617763525023
# (validation) epoch 198, avg. validation loss: 5633.847086588542
# (train) epoch 199,      avg. train loss     : 5481.031201171875
# (validation) epoch 199, avg. validation loss: 5818.03369140625
# (train) epoch 200,      avg. train loss     : 5462.176909803807
# (validation) epoch 200, avg. validation loss: 5956.629557291667
# (train) epoch 201,      avg. train loss     : 5433.366995858788
# (validation) epoch 201, avg. validation loss: 5624.7392578125
# (train) epoch 202,      avg. train loss     : 5450.734232554041
# (validation) epoch 202, avg. validation loss: 5565.151041666667
# (train) epoch 203,      avg. train loss     : 5429.201641799812
# (validation) epoch 203, avg. validation loss: 5605.227701822917
# (train) epoch 204,      avg. train loss     : 5410.554778547932
# (validation) epoch 204, avg. validation loss: 5971.75634765625
# (train) epoch 205,      avg. train loss     : 5401.820486151903
# (validation) epoch 205, avg. validation loss: 5584.834716796875
# (train) epoch 206,      avg. train loss     : 5363.286939394385
# (validation) epoch 206, avg. validation loss: 5605.682047526042
# (train) epoch 207,      avg. train loss     : 5436.7970916059685
# (validation) epoch 207, avg. validation loss: 5568.597819010417
# (train) epoch 208,      avg. train loss     : 5374.174719513628
# (validation) epoch 208, avg. validation loss: 5842.104736328125
# (train) epoch 209,      avg. train loss     : 5334.75074563851
# (validation) epoch 209, avg. validation loss: 5479.791585286458
# (train) epoch 210,      avg. train loss     : 5356.313541177162
# (validation) epoch 210, avg. validation loss: 5461.129150390625
# (train) epoch 211,      avg. train loss     : 5338.474058681861
# (validation) epoch 211, avg. validation loss: 5448.149820963542
# (train) epoch 212,      avg. train loss     : 5356.202717119948
# (validation) epoch 212, avg. validation loss: 5502.476888020833
# (train) epoch 213,      avg. train loss     : 5322.680356408599
# (validation) epoch 213, avg. validation loss: 5498.466878255208
# (train) epoch 214,      avg. train loss     : 5326.691096760456
# (validation) epoch 214, avg. validation loss: 5434.068440755208
# (train) epoch 215,      avg. train loss     : 5325.398795817669
# (validation) epoch 215, avg. validation loss: 5548.439127604167
# (train) epoch 216,      avg. train loss     : 5299.957294848449
# (validation) epoch 216, avg. validation loss: 5446.842203776042
# (train) epoch 217,      avg. train loss     : 5342.7260125411185
# (validation) epoch 217, avg. validation loss: 5489.500732421875
# (train) epoch 218,      avg. train loss     : 5303.39630998884
# (validation) epoch 218, avg. validation loss: 5651.107584635417
# (train) epoch 219,      avg. train loss     : 5298.482916397439
# (validation) epoch 219, avg. validation loss: 5380.55908203125
# (train) epoch 220,      avg. train loss     : 5299.763460775964
# (validation) epoch 220, avg. validation loss: 5343.221272786458
# (train) epoch 221,      avg. train loss     : 5292.474344308036
# (validation) epoch 221, avg. validation loss: 5420.34033203125
# (train) epoch 222,      avg. train loss     : 5258.729296140743
# (validation) epoch 222, avg. validation loss: 5449.486979166667
# (train) epoch 223,      avg. train loss     : 5275.981350960409
# (validation) epoch 223, avg. validation loss: 5459.767740885417
# (train) epoch 224,      avg. train loss     : 5298.929687867128
# (validation) epoch 224, avg. validation loss: 5766.274251302083
# (train) epoch 225,      avg. train loss     : 5244.534151418586
# (validation) epoch 225, avg. validation loss: 5650.442057291667
# (train) epoch 226,      avg. train loss     : 5265.324057580475
# (validation) epoch 226, avg. validation loss: 5396.820068359375
# (train) epoch 227,      avg. train loss     : 5254.416017460644
# (validation) epoch 227, avg. validation loss: 5364.832275390625
# (train) epoch 228,      avg. train loss     : 5214.558087112312
# (validation) epoch 228, avg. validation loss: 5384.3628336588545
# (train) epoch 229,      avg. train loss     : 5273.863969249295
# (validation) epoch 229, avg. validation loss: 5592.048665364583
# (train) epoch 230,      avg. train loss     : 5242.988636630639
# (validation) epoch 230, avg. validation loss: 5353.285970052083
# (train) epoch 231,      avg. train loss     : 5228.958007078242
# (validation) epoch 231, avg. validation loss: 5650.148763020833
# (train) epoch 232,      avg. train loss     : 5230.504926500822
# (validation) epoch 232, avg. validation loss: 5284.943440755208
# (train) epoch 233,      avg. train loss     : 5212.346481805099
# (validation) epoch 233, avg. validation loss: 5255.353678385417
# (train) epoch 234,      avg. train loss     : 5199.254795435855
# (validation) epoch 234, avg. validation loss: 5496.977294921875
# (train) epoch 235,      avg. train loss     : 5213.878569960057
# (validation) epoch 235, avg. validation loss: 5258.026285807292
# (train) epoch 236,      avg. train loss     : 5189.33510595336
# (validation) epoch 236, avg. validation loss: 5269.039957682292
# (train) epoch 237,      avg. train loss     : 5183.41242327009
# (validation) epoch 237, avg. validation loss: 5564.201416015625
# (train) epoch 238,      avg. train loss     : 5186.481017240367
# (validation) epoch 238, avg. validation loss: 5419.036783854167
# (train) epoch 239,      avg. train loss     : 5160.196926030898
# (validation) epoch 239, avg. validation loss: 5302.917236328125
# (train) epoch 240,      avg. train loss     : 5181.448589491306
# (validation) epoch 240, avg. validation loss: 5371.04345703125
# (train) epoch 241,      avg. train loss     : 5153.936936824483
# (validation) epoch 241, avg. validation loss: 5374.7012939453125
# (train) epoch 242,      avg. train loss     : 5173.284086803924
# (validation) epoch 242, avg. validation loss: 5525.304606119792
# (train) epoch 243,      avg. train loss     : 5151.924248120301
# (validation) epoch 243, avg. validation loss: 5288.335123697917
# (train) epoch 244,      avg. train loss     : 5157.463335217928
# (validation) epoch 244, avg. validation loss: 5276.302327473958
# (train) epoch 245,      avg. train loss     : 5140.782186912594
# (validation) epoch 245, avg. validation loss: 5151.1617431640625
# (train) epoch 246,      avg. train loss     : 5119.602950246711
# (validation) epoch 246, avg. validation loss: 5242.4208984375
# (train) epoch 247,      avg. train loss     : 5145.629264934798
# (validation) epoch 247, avg. validation loss: 5162.906331380208
# (train) epoch 248,      avg. train loss     : 5156.934767093515
# (validation) epoch 248, avg. validation loss: 5482.388020833333
# (train) epoch 249,      avg. train loss     : 5124.6327717487075
# (validation) epoch 249, avg. validation loss: 5433.123942057292
# (train) epoch 250,      avg. train loss     : 5156.6768238956765
# (validation) epoch 250, avg. validation loss: 5605.241617838542
# Entire training of austin's model took 351.4850423336029 seconds.
# Starting training for miami.
# train_samples_per_epoch = 54464
# validation_samples_per_epoch = 512
# (train) epoch 1,      avg. train loss     : 9958162.97411134
# (validation) epoch 1, avg. validation loss: 133466.228515625
# (train) epoch 2,      avg. train loss     : 162859.5749118684
# (validation) epoch 2, avg. validation loss: 191348.861328125
# (train) epoch 3,      avg. train loss     : 185029.8210010282
# (validation) epoch 3, avg. validation loss: 910326.5625
# (train) epoch 4,      avg. train loss     : 276206.80819440365
# (validation) epoch 4, avg. validation loss: 216963.345703125
# (train) epoch 5,      avg. train loss     : 194203.47745758668
# (validation) epoch 5, avg. validation loss: 240401.5
# (train) epoch 6,      avg. train loss     : 203719.27222110017
# (validation) epoch 6, avg. validation loss: 189027.357421875
# (train) epoch 7,      avg. train loss     : 202388.86692585927
# (validation) epoch 7, avg. validation loss: 386156.85546875
# (train) epoch 8,      avg. train loss     : 155259.8253295755
# (validation) epoch 8, avg. validation loss: 199272.462890625
# (train) epoch 9,      avg. train loss     : 194527.7256077409
# (validation) epoch 9, avg. validation loss: 220449.033203125
# (train) epoch 10,      avg. train loss     : 137098.20390533196
# (validation) epoch 10, avg. validation loss: 74798.6943359375
# (train) epoch 11,      avg. train loss     : 145324.31838003083
# (validation) epoch 11, avg. validation loss: 167024.9365234375
# (train) epoch 12,      avg. train loss     : 136602.6768920755
# (validation) epoch 12, avg. validation loss: 284617.474609375
# (train) epoch 13,      avg. train loss     : 143392.00256362002
# (validation) epoch 13, avg. validation loss: 120416.443359375
# (train) epoch 14,      avg. train loss     : 100732.57987386163
# (validation) epoch 14, avg. validation loss: 121247.576171875
# (train) epoch 15,      avg. train loss     : 135717.8799413374
# (validation) epoch 15, avg. validation loss: 234473.984375
# (train) epoch 16,      avg. train loss     : 139964.3418014652
# (validation) epoch 16, avg. validation loss: 44851.693359375
# (train) epoch 17,      avg. train loss     : 72484.84465885723
# (validation) epoch 17, avg. validation loss: 61071.01416015625
# (train) epoch 18,      avg. train loss     : 106288.0929811435
# (validation) epoch 18, avg. validation loss: 139111.4130859375
# (train) epoch 19,      avg. train loss     : 114486.49948360385
# (validation) epoch 19, avg. validation loss: 85922.06396484375
# (train) epoch 20,      avg. train loss     : 90448.18621933754
# (validation) epoch 20, avg. validation loss: 105748.873046875
# (train) epoch 21,      avg. train loss     : 145817.55365929788
# (validation) epoch 21, avg. validation loss: 157113.2587890625
# (train) epoch 22,      avg. train loss     : 61306.14455190585
# (validation) epoch 22, avg. validation loss: 128389.7685546875
# (train) epoch 23,      avg. train loss     : 76449.17959569625
# (validation) epoch 23, avg. validation loss: 131907.2998046875
# (train) epoch 24,      avg. train loss     : 73550.951171875
# (validation) epoch 24, avg. validation loss: 78005.001953125
# (train) epoch 25,      avg. train loss     : 78494.35118610458
# (validation) epoch 25, avg. validation loss: 49359.380859375
# (train) epoch 26,      avg. train loss     : 89688.26401154892
# (validation) epoch 26, avg. validation loss: 132639.30078125
# (train) epoch 27,      avg. train loss     : 65129.99283471651
# (validation) epoch 27, avg. validation loss: 48321.181640625
# (train) epoch 28,      avg. train loss     : 85178.91434479656
# (validation) epoch 28, avg. validation loss: 60112.48193359375
# (train) epoch 29,      avg. train loss     : 88519.89460239791
# (validation) epoch 29, avg. validation loss: 63387.27490234375
# (train) epoch 30,      avg. train loss     : 65879.56447607595
# (validation) epoch 30, avg. validation loss: 38276.7529296875
# (train) epoch 31,      avg. train loss     : 65137.0179614057
# (validation) epoch 31, avg. validation loss: 37154.572265625
# (train) epoch 32,      avg. train loss     : 65003.43813918368
# (validation) epoch 32, avg. validation loss: 49025.0859375
# (train) epoch 33,      avg. train loss     : 84556.19674463866
# (validation) epoch 33, avg. validation loss: 41013.50439453125
# (train) epoch 34,      avg. train loss     : 17532.687675574693
# (validation) epoch 34, avg. validation loss: 18356.20849609375
# (train) epoch 35,      avg. train loss     : 15699.362374687867
# (validation) epoch 35, avg. validation loss: 17832.137939453125
# (train) epoch 36,      avg. train loss     : 14593.042073663337
# (validation) epoch 36, avg. validation loss: 19433.2822265625
# (train) epoch 37,      avg. train loss     : 13765.425454199103
# (validation) epoch 37, avg. validation loss: 13842.571533203125
# (train) epoch 38,      avg. train loss     : 13443.953492215041
# (validation) epoch 38, avg. validation loss: 13270.152465820312
# (train) epoch 39,      avg. train loss     : 13403.598353958578
# (validation) epoch 39, avg. validation loss: 14053.002319335938
# (train) epoch 40,      avg. train loss     : 12932.18290407425
# (validation) epoch 40, avg. validation loss: 14725.645385742188
# (train) epoch 41,      avg. train loss     : 12720.355239814373
# (validation) epoch 41, avg. validation loss: 10451.174072265625
# (train) epoch 42,      avg. train loss     : 12440.127543537934
# (validation) epoch 42, avg. validation loss: 12473.982177734375
# (train) epoch 43,      avg. train loss     : 12737.337270949618
# (validation) epoch 43, avg. validation loss: 13612.32763671875
# (train) epoch 44,      avg. train loss     : 12541.342785486744
# (validation) epoch 44, avg. validation loss: 10896.92919921875
# (train) epoch 45,      avg. train loss     : 12149.42389697782
# (validation) epoch 45, avg. validation loss: 18189.490356445312
# (train) epoch 46,      avg. train loss     : 12172.205662226424
# (validation) epoch 46, avg. validation loss: 11713.10009765625
# (train) epoch 47,      avg. train loss     : 12365.472278133262
# (validation) epoch 47, avg. validation loss: 11013.806030273438
# (train) epoch 48,      avg. train loss     : 12775.165009226277
# (validation) epoch 48, avg. validation loss: 11827.480346679688
# (train) epoch 49,      avg. train loss     : 12270.866978072672
# (validation) epoch 49, avg. validation loss: 12225.94287109375
# (train) epoch 50,      avg. train loss     : 12120.841658595586
# (validation) epoch 50, avg. validation loss: 10843.124877929688
# (train) epoch 51,      avg. train loss     : 12005.359226966437
# (validation) epoch 51, avg. validation loss: 11202.433715820312
# (train) epoch 52,      avg. train loss     : 12228.455494684562
# (validation) epoch 52, avg. validation loss: 12693.761108398438
# (train) epoch 53,      avg. train loss     : 12185.416301364205
# (validation) epoch 53, avg. validation loss: 11959.645385742188
# (train) epoch 54,      avg. train loss     : 11611.455366159298
# (validation) epoch 54, avg. validation loss: 10553.351623535156
# (train) epoch 55,      avg. train loss     : 12032.399872507527
# (validation) epoch 55, avg. validation loss: 10831.154907226562
# (train) epoch 56,      avg. train loss     : 12305.079228940218
# (validation) epoch 56, avg. validation loss: 11333.289428710938
# (train) epoch 57,      avg. train loss     : 12029.624278766709
# (validation) epoch 57, avg. validation loss: 11387.106689453125
# (train) epoch 58,      avg. train loss     : 11739.412113391414
# (validation) epoch 58, avg. validation loss: 11074.843627929688
# (train) epoch 59,      avg. train loss     : 12310.526079726975
# (validation) epoch 59, avg. validation loss: 10443.638916015625
# (train) epoch 60,      avg. train loss     : 11752.877673784518
# (validation) epoch 60, avg. validation loss: 10495.280517578125
# (train) epoch 61,      avg. train loss     : 11981.435565809526
# (validation) epoch 61, avg. validation loss: 29129.80712890625
# (train) epoch 62,      avg. train loss     : 12186.952826637778
# (validation) epoch 62, avg. validation loss: 13953.601196289062
# (train) epoch 63,      avg. train loss     : 11856.752144191576
# (validation) epoch 63, avg. validation loss: 13199.147583007812
# (train) epoch 64,      avg. train loss     : 11338.484067457402
# (validation) epoch 64, avg. validation loss: 13234.13818359375
# (train) epoch 65,      avg. train loss     : 11385.88179978977
# (validation) epoch 65, avg. validation loss: 12546.610473632812
# (train) epoch 66,      avg. train loss     : 12172.470286565438
# (validation) epoch 66, avg. validation loss: 13036.82763671875
# (train) epoch 67,      avg. train loss     : 11651.360613203216
# (validation) epoch 67, avg. validation loss: 12805.098510742188
# (train) epoch 68,      avg. train loss     : 11333.853873659666
# (validation) epoch 68, avg. validation loss: 9824.817932128906
# (train) epoch 69,      avg. train loss     : 11231.44960547334
# (validation) epoch 69, avg. validation loss: 10778.404052734375
# (train) epoch 70,      avg. train loss     : 11861.49543850066
# (validation) epoch 70, avg. validation loss: 11444.584716796875
# (train) epoch 71,      avg. train loss     : 11395.55872170149
# (validation) epoch 71, avg. validation loss: 11789.022705078125
# (train) epoch 72,      avg. train loss     : 11629.621220553943
# (validation) epoch 72, avg. validation loss: 10408.503662109375
# (train) epoch 73,      avg. train loss     : 11228.752977884475
# (validation) epoch 73, avg. validation loss: 10825.756958007812
# (train) epoch 74,      avg. train loss     : 11343.614543551705
# (validation) epoch 74, avg. validation loss: 13996.146362304688
# (train) epoch 75,      avg. train loss     : 11223.995645632895
# (validation) epoch 75, avg. validation loss: 10403.782348632812
# (train) epoch 76,      avg. train loss     : 11676.78852659555
# (validation) epoch 76, avg. validation loss: 12150.0146484375
# (train) epoch 77,      avg. train loss     : 11350.217152040797
# (validation) epoch 77, avg. validation loss: 15172.776977539062
# (train) epoch 78,      avg. train loss     : 11354.423608369749
# (validation) epoch 78, avg. validation loss: 11677.2724609375
# (train) epoch 79,      avg. train loss     : 11236.757829139431
# (validation) epoch 79, avg. validation loss: 11405.855102539062
# (train) epoch 80,      avg. train loss     : 11499.164691355758
# (validation) epoch 80, avg. validation loss: 16565.910278320312
# (train) epoch 81,      avg. train loss     : 11226.353842675897
# (validation) epoch 81, avg. validation loss: 10587.538940429688
# (train) epoch 82,      avg. train loss     : 10996.182988418956
# (validation) epoch 82, avg. validation loss: 27743.84521484375
# (train) epoch 83,      avg. train loss     : 11608.73047506151
# (validation) epoch 83, avg. validation loss: 9769.971069335938
# (train) epoch 84,      avg. train loss     : 10943.207992320615
# (validation) epoch 84, avg. validation loss: 13006.481567382812
# (train) epoch 85,      avg. train loss     : 11651.722306821937
# (validation) epoch 85, avg. validation loss: 13141.643432617188
# (train) epoch 86,      avg. train loss     : 10898.763463595218
# (validation) epoch 86, avg. validation loss: 9347.758422851562
# (train) epoch 87,      avg. train loss     : 11305.747818513146
# (validation) epoch 87, avg. validation loss: 9830.397705078125
# (train) epoch 88,      avg. train loss     : 11344.107260644647
# (validation) epoch 88, avg. validation loss: 10223.887329101562
# (train) epoch 89,      avg. train loss     : 10967.26272801759
# (validation) epoch 89, avg. validation loss: 9881.620239257812
# (train) epoch 90,      avg. train loss     : 11422.86998464582
# (validation) epoch 90, avg. validation loss: 9906.875854492188
# (train) epoch 91,      avg. train loss     : 10706.452534587066
# (validation) epoch 91, avg. validation loss: 11335.50537109375
# (train) epoch 92,      avg. train loss     : 11160.305563078364
# (validation) epoch 92, avg. validation loss: 9311.354614257812
# (train) epoch 93,      avg. train loss     : 11004.097131247247
# (validation) epoch 93, avg. validation loss: 10857.411743164062
# (train) epoch 94,      avg. train loss     : 11234.011506453804
# (validation) epoch 94, avg. validation loss: 12719.766967773438
# (train) epoch 95,      avg. train loss     : 11255.023317581337
# (validation) epoch 95, avg. validation loss: 9592.881103515625
# (train) epoch 96,      avg. train loss     : 10991.403861380912
# (validation) epoch 96, avg. validation loss: 9416.939208984375
# (train) epoch 97,      avg. train loss     : 11008.750154918846
# (validation) epoch 97, avg. validation loss: 10221.130615234375
# (train) epoch 98,      avg. train loss     : 10728.543397932579
# (validation) epoch 98, avg. validation loss: 12563.089233398438
# (train) epoch 99,      avg. train loss     : 11189.066352889064
# (validation) epoch 99, avg. validation loss: 9974.558959960938
# (train) epoch 100,      avg. train loss     : 10901.194365773723
# (validation) epoch 100, avg. validation loss: 9947.180419921875
# (train) epoch 101,      avg. train loss     : 11145.048052383225
# (validation) epoch 101, avg. validation loss: 15664.711547851562
# (train) epoch 102,      avg. train loss     : 11105.718005241995
# (validation) epoch 102, avg. validation loss: 15199.753295898438
# (train) epoch 103,      avg. train loss     : 8341.674276815878
# (validation) epoch 103, avg. validation loss: 8431.635375976562
# (train) epoch 104,      avg. train loss     : 8325.952082453547
# (validation) epoch 104, avg. validation loss: 8317.868347167969
# (train) epoch 105,      avg. train loss     : 8322.842510075463
# (validation) epoch 105, avg. validation loss: 8381.865600585938
# (train) epoch 106,      avg. train loss     : 8292.369114805193
# (validation) epoch 106, avg. validation loss: 8943.923278808594
# (train) epoch 107,      avg. train loss     : 8279.340450228592
# (validation) epoch 107, avg. validation loss: 8313.936645507812
# (train) epoch 108,      avg. train loss     : 8261.555677833065
# (validation) epoch 108, avg. validation loss: 8301.896057128906
# (train) epoch 109,      avg. train loss     : 8219.596508129223
# (validation) epoch 109, avg. validation loss: 8763.720092773438
# (train) epoch 110,      avg. train loss     : 8206.02400094558
# (validation) epoch 110, avg. validation loss: 8552.991333007812
# (train) epoch 111,      avg. train loss     : 8169.334406098524
# (validation) epoch 111, avg. validation loss: 8425.934509277344
# (train) epoch 112,      avg. train loss     : 8175.036408797554
# (validation) epoch 112, avg. validation loss: 8785.525268554688
# (train) epoch 113,      avg. train loss     : 8162.94228125459
# (validation) epoch 113, avg. validation loss: 8214.616027832031
# (train) epoch 114,      avg. train loss     : 8102.019892153533
# (validation) epoch 114, avg. validation loss: 8037.937438964844
# (train) epoch 115,      avg. train loss     : 8103.977530742784
# (validation) epoch 115, avg. validation loss: 8038.551696777344
# (train) epoch 116,      avg. train loss     : 8102.211392502387
# (validation) epoch 116, avg. validation loss: 8412.361267089844
# (train) epoch 117,      avg. train loss     : 8060.75084057818
# (validation) epoch 117, avg. validation loss: 7987.4051513671875
# (train) epoch 118,      avg. train loss     : 8058.549284848707
# (validation) epoch 118, avg. validation loss: 8057.8475341796875
# (train) epoch 119,      avg. train loss     : 8020.661811012779
# (validation) epoch 119, avg. validation loss: 8029.733825683594
# (train) epoch 120,      avg. train loss     : 8019.661255600029
# (validation) epoch 120, avg. validation loss: 8151.499450683594
# (train) epoch 121,      avg. train loss     : 8000.96494616857
# (validation) epoch 121, avg. validation loss: 8244.079040527344
# (train) epoch 122,      avg. train loss     : 7983.442442484944
# (validation) epoch 122, avg. validation loss: 8111.356750488281
# (train) epoch 123,      avg. train loss     : 8001.678456468952
# (validation) epoch 123, avg. validation loss: 7995.973083496094
# (train) epoch 124,      avg. train loss     : 7995.886831783379
# (validation) epoch 124, avg. validation loss: 8087.7677001953125
# (train) epoch 125,      avg. train loss     : 7954.703576559746
# (validation) epoch 125, avg. validation loss: 7790.9451904296875
# (train) epoch 126,      avg. train loss     : 7890.654152857851
# ...
# (train) epoch 125,      avg. train loss     : 12953.056791068411
# (validation) epoch 125, avg. validation loss: 10359.494140625
# (train) epoch 126,      avg. train loss     : 12933.119114231418
# (validation) epoch 126, avg. validation loss: 10341.35546875
# (train) epoch 127,      avg. train loss     : 12962.454531777872
# (validation) epoch 127, avg. validation loss: 10335.59375
# (train) epoch 128,      avg. train loss     : 12953.004172825169
# (validation) epoch 128, avg. validation loss: 10346.806640625
# (train) epoch 129,      avg. train loss     : 12943.52815139358
# (validation) epoch 129, avg. validation loss: 10339.857421875
# (train) epoch 130,      avg. train loss     : 12951.910847761825
# (validation) epoch 130, avg. validation loss: 10346.1083984375
# (train) epoch 131,      avg. train loss     : 12951.815936444256
# (validation) epoch 131, avg. validation loss: 10350.35546875
# (train) epoch 132,      avg. train loss     : 12945.378861380912
# (validation) epoch 132, avg. validation loss: 10333.125
# (train) epoch 133,      avg. train loss     : 12954.030115076013
# (validation) epoch 133, avg. validation loss: 10349.5166015625
# (train) epoch 134,      avg. train loss     : 12956.072748627534
# (validation) epoch 134, avg. validation loss: 10350.19921875
# (train) epoch 135,      avg. train loss     : 12966.505769636824
# (validation) epoch 135, avg. validation loss: 10341.53125
# (train) epoch 136,      avg. train loss     : 12937.169388724662
# (validation) epoch 136, avg. validation loss: 10348.3583984375
# (train) epoch 137,      avg. train loss     : 12949.267567567567
# (validation) epoch 137, avg. validation loss: 10347.66015625
# (train) epoch 138,      avg. train loss     : 12954.044074641048
# (validation) epoch 138, avg. validation loss: 10346.4111328125
# (train) epoch 139,      avg. train loss     : 12941.483849767736
# (validation) epoch 139, avg. validation loss: 10345.365234375
# (train) epoch 140,      avg. train loss     : 12949.210845122467
# (validation) epoch 140, avg. validation loss: 10345.359375
# (train) epoch 141,      avg. train loss     : 12962.982208086993
# (validation) epoch 141, avg. validation loss: 10345.470703125
# (train) epoch 142,      avg. train loss     : 12947.560441300675
# (validation) epoch 142, avg. validation loss: 10345.18359375
# (train) epoch 143,      avg. train loss     : 12932.529998944257
# (validation) epoch 143, avg. validation loss: 10344.59375
# (train) epoch 144,      avg. train loss     : 12934.05712890625
# (validation) epoch 144, avg. validation loss: 10344.47265625
# (train) epoch 145,      avg. train loss     : 12949.962162162163
# (validation) epoch 145, avg. validation loss: 10345.076171875
# (train) epoch 146,      avg. train loss     : 12954.31171875
# (validation) epoch 146, avg. validation loss: 10344.7216796875
# (train) epoch 147,      avg. train loss     : 12930.070085515203
# (validation) epoch 147, avg. validation loss: 10344.611328125
# (train) epoch 148,      avg. train loss     : 12943.108408994933
# (validation) epoch 148, avg. validation loss: 10345.2861328125
# (train) epoch 149,      avg. train loss     : 12962.192628272804
# (validation) epoch 149, avg. validation loss: 10346.193359375
# (train) epoch 150,      avg. train loss     : 12948.193800147805
# (validation) epoch 150, avg. validation loss: 10345.611328125
# (train) epoch 151,      avg. train loss     : 12949.759293179899
# (validation) epoch 151, avg. validation loss: 10345.587890625
# (train) epoch 152,      avg. train loss     : 12931.865263407939
# (validation) epoch 152, avg. validation loss: 10345.78515625
# (train) epoch 153,      avg. train loss     : 12941.759733952702
# (validation) epoch 153, avg. validation loss: 10346.17578125
# (train) epoch 154,      avg. train loss     : 12930.05841163429
# (validation) epoch 154, avg. validation loss: 10345.826171875
# (train) epoch 155,      avg. train loss     : 12953.900754856419
# (validation) epoch 155, avg. validation loss: 10345.693359375
# (train) epoch 156,      avg. train loss     : 12957.780122994089
# (validation) epoch 156, avg. validation loss: 10345.66015625
# (train) epoch 157,      avg. train loss     : 12949.0897619299
# (validation) epoch 157, avg. validation loss: 10346.0322265625
# (train) epoch 158,      avg. train loss     : 12938.866876055743
# (validation) epoch 158, avg. validation loss: 10346.712890625
# (train) epoch 159,      avg. train loss     : 12949.188692989865
# (validation) epoch 159, avg. validation loss: 10346.53515625
# (train) epoch 160,      avg. train loss     : 12959.679455236486
# (validation) epoch 160, avg. validation loss: 10346.9609375
# (train) epoch 161,      avg. train loss     : 12929.802449324325
# (validation) epoch 161, avg. validation loss: 10346.40234375
# (train) epoch 162,      avg. train loss     : 12936.741775760134
# (validation) epoch 162, avg. validation loss: 10346.7236328125
# (train) epoch 163,      avg. train loss     : 12958.149838999156
# (validation) epoch 163, avg. validation loss: 10346.890625
# (train) epoch 164,      avg. train loss     : 12953.93409522804
# (validation) epoch 164, avg. validation loss: 10346.9833984375
# (train) epoch 165,      avg. train loss     : 12953.109739231419
# (validation) epoch 165, avg. validation loss: 10346.9091796875
# (train) epoch 166,      avg. train loss     : 12943.406371410472
# (validation) epoch 166, avg. validation loss: 10347.2138671875
# (train) epoch 167,      avg. train loss     : 12950.695225401183
# (validation) epoch 167, avg. validation loss: 10347.61328125
# (train) epoch 168,      avg. train loss     : 12948.731756756757
# (validation) epoch 168, avg. validation loss: 10346.3828125
# (train) epoch 169,      avg. train loss     : 12928.027871621622
# (validation) epoch 169, avg. validation loss: 10346.197265625
# (train) epoch 170,      avg. train loss     : 12940.938935810811
# (validation) epoch 170, avg. validation loss: 10347.2734375
# (train) epoch 171,      avg. train loss     : 12940.055384290541
# (validation) epoch 171, avg. validation loss: 10347.51171875
# (train) epoch 172,      avg. train loss     : 12948.335275021114
# (validation) epoch 172, avg. validation loss: 10346.900390625
# (train) epoch 173,      avg. train loss     : 12940.868475506757
# (validation) epoch 173, avg. validation loss: 10347.224609375
# (train) epoch 174,      avg. train loss     : 12957.219103673986
# (validation) epoch 174, avg. validation loss: 10346.9130859375
# (train) epoch 175,      avg. train loss     : 12949.40789695946
# (validation) epoch 175, avg. validation loss: 10347.7822265625
# (train) epoch 176,      avg. train loss     : 12930.652726456925
# (validation) epoch 176, avg. validation loss: 10347.07421875
# (train) epoch 177,      avg. train loss     : 12941.063803842906
# (validation) epoch 177, avg. validation loss: 10348.4970703125
# (train) epoch 178,      avg. train loss     : 12946.104613597972
# (validation) epoch 178, avg. validation loss: 10347.39453125
# (train) epoch 179,      avg. train loss     : 12947.62395481419
# (validation) epoch 179, avg. validation loss: 10347.8359375
# (train) epoch 180,      avg. train loss     : 12958.166036739865
# (validation) epoch 180, avg. validation loss: 10348.046875
# (train) epoch 181,      avg. train loss     : 12938.803051097973
# (validation) epoch 181, avg. validation loss: 10348.10546875
# (train) epoch 182,      avg. train loss     : 12957.898347761824
# (validation) epoch 182, avg. validation loss: 10347.5166015625
# (train) epoch 183,      avg. train loss     : 12945.720093433278
# (validation) epoch 183, avg. validation loss: 10347.5244140625
# (train) epoch 184,      avg. train loss     : 12953.143412162162
# (validation) epoch 184, avg. validation loss: 10347.71875
# (train) epoch 185,      avg. train loss     : 12946.066028821791
# (validation) epoch 185, avg. validation loss: 10347.423828125
# (train) epoch 186,      avg. train loss     : 12960.29744510135
# (validation) epoch 186, avg. validation loss: 10347.44921875
# (train) epoch 187,      avg. train loss     : 12953.134480574325
# (validation) epoch 187, avg. validation loss: 10347.533203125
# (train) epoch 188,      avg. train loss     : 12925.532453547297
# (validation) epoch 188, avg. validation loss: 10347.3251953125
# (train) epoch 189,      avg. train loss     : 12942.526971600506
# (validation) epoch 189, avg. validation loss: 10346.935546875
# (train) epoch 190,      avg. train loss     : 12951.09775390625
# (validation) epoch 190, avg. validation loss: 10346.646484375
# (train) epoch 191,      avg. train loss     : 12946.531379328548
# (validation) epoch 191, avg. validation loss: 10347.37109375
# (train) epoch 192,      avg. train loss     : 12953.372492609797
# (validation) epoch 192, avg. validation loss: 10346.9580078125
# (train) epoch 193,      avg. train loss     : 12947.533443306587
# (validation) epoch 193, avg. validation loss: 10346.69921875
# (train) epoch 194,      avg. train loss     : 12945.736217271959
# (validation) epoch 194, avg. validation loss: 10347.1630859375
# (train) epoch 195,      avg. train loss     : 12948.286098500845
# (validation) epoch 195, avg. validation loss: 10347.48046875
# (train) epoch 196,      avg. train loss     : 12945.94669288429
# (validation) epoch 196, avg. validation loss: 10347.1943359375
# (train) epoch 197,      avg. train loss     : 12953.265730574325
# (validation) epoch 197, avg. validation loss: 10346.771484375
# (train) epoch 198,      avg. train loss     : 12950.513861908783
# (validation) epoch 198, avg. validation loss: 10347.6298828125
# (train) epoch 199,      avg. train loss     : 12946.63583984375
# (validation) epoch 199, avg. validation loss: 10347.716796875
# (train) epoch 200,      avg. train loss     : 12955.467987225507
# (validation) epoch 200, avg. validation loss: 10347.05859375
# (train) epoch 201,      avg. train loss     : 12950.18359375
# (validation) epoch 201, avg. validation loss: 10346.8779296875
# (train) epoch 202,      avg. train loss     : 12952.614574535473
# (validation) epoch 202, avg. validation loss: 10347.3662109375
# (train) epoch 203,      avg. train loss     : 12944.580695734798
# (validation) epoch 203, avg. validation loss: 10346.9814453125
# (train) epoch 204,      avg. train loss     : 12951.319679054053
# (validation) epoch 204, avg. validation loss: 10346.84375
# (train) epoch 205,      avg. train loss     : 12951.925311444256
# (validation) epoch 205, avg. validation loss: 10347.22265625
# (train) epoch 206,      avg. train loss     : 12950.767440878379
# (validation) epoch 206, avg. validation loss: 10347.1513671875
# (train) epoch 207,      avg. train loss     : 12939.340939083615
# (validation) epoch 207, avg. validation loss: 10347.943359375
# (train) epoch 208,      avg. train loss     : 12939.403061655405
# (validation) epoch 208, avg. validation loss: 10348.3369140625
# (train) epoch 209,      avg. train loss     : 12953.504106841216
# (validation) epoch 209, avg. validation loss: 10348.0478515625
# (train) epoch 210,      avg. train loss     : 12947.144752956081
# (validation) epoch 210, avg. validation loss: 10348.197265625
# (train) epoch 211,      avg. train loss     : 12955.744230363176
# (validation) epoch 211, avg. validation loss: 10347.7890625
# (train) epoch 212,      avg. train loss     : 12929.109797297297
# (validation) epoch 212, avg. validation loss: 10347.44921875
# (train) epoch 213,      avg. train loss     : 12948.961708192568
# (validation) epoch 213, avg. validation loss: 10347.8759765625
# (train) epoch 214,      avg. train loss     : 12940.913019953547
# (validation) epoch 214, avg. validation loss: 10347.427734375
# (train) epoch 215,      avg. train loss     : 12942.613339315878
# (validation) epoch 215, avg. validation loss: 10347.83984375
# (train) epoch 216,      avg. train loss     : 12931.89934543919
# (validation) epoch 216, avg. validation loss: 10347.482421875
# (train) epoch 217,      avg. train loss     : 12951.499152766048
# (validation) epoch 217, avg. validation loss: 10347.154296875
# (train) epoch 218,      avg. train loss     : 12947.07734375
# (validation) epoch 218, avg. validation loss: 10346.96484375
# (train) epoch 219,      avg. train loss     : 12954.892918602196
# (validation) epoch 219, avg. validation loss: 10347.203125
# (train) epoch 220,      avg. train loss     : 12955.160256545609
# (validation) epoch 220, avg. validation loss: 10347.03515625
# (train) epoch 221,      avg. train loss     : 12946.072965054898
# (validation) epoch 221, avg. validation loss: 10347.021484375
# (train) epoch 222,      avg. train loss     : 12952.07582347973
# (validation) epoch 222, avg. validation loss: 10347.70703125
# (train) epoch 223,      avg. train loss     : 12942.971046241553
# (validation) epoch 223, avg. validation loss: 10347.734375
# (train) epoch 224,      avg. train loss     : 12955.161808488176
# (validation) epoch 224, avg. validation loss: 10347.900390625
# (train) epoch 225,      avg. train loss     : 12943.597244510134
# (validation) epoch 225, avg. validation loss: 10347.787109375
# (train) epoch 226,      avg. train loss     : 12952.94279983108
# (validation) epoch 226, avg. validation loss: 10348.0546875
# (train) epoch 227,      avg. train loss     : 12954.791865498311
# (validation) epoch 227, avg. validation loss: 10348.1171875
# (train) epoch 228,      avg. train loss     : 12936.338099134291
# (validation) epoch 228, avg. validation loss: 10348.4609375
# (train) epoch 229,      avg. train loss     : 12949.237655722129
# (validation) epoch 229, avg. validation loss: 10348.2734375
# (train) epoch 230,      avg. train loss     : 12934.918599556588
# (validation) epoch 230, avg. validation loss: 10348.4716796875
# (train) epoch 231,      avg. train loss     : 12952.185090266048
# (validation) epoch 231, avg. validation loss: 10348.7216796875
# (train) epoch 232,      avg. train loss     : 12951.86180320946
# (validation) epoch 232, avg. validation loss: 10348.162109375
# (train) epoch 233,      avg. train loss     : 12950.923265941723
# (validation) epoch 233, avg. validation loss: 10348.3671875
# (train) epoch 234,      avg. train loss     : 12943.31665698902
# (validation) epoch 234, avg. validation loss: 10348.498046875
# (train) epoch 235,      avg. train loss     : 12938.833171452703
# (validation) epoch 235, avg. validation loss: 10348.09375
# (train) epoch 236,      avg. train loss     : 12948.868198374155
# (validation) epoch 236, avg. validation loss: 10347.765625
# (train) epoch 237,      avg. train loss     : 12946.602116765203
# (validation) epoch 237, avg. validation loss: 10348.4111328125
# (train) epoch 238,      avg. train loss     : 12943.28069045608
# (validation) epoch 238, avg. validation loss: 10348.548828125
# (train) epoch 239,      avg. train loss     : 12948.828951119089
# (validation) epoch 239, avg. validation loss: 10348.396484375
# (train) epoch 240,      avg. train loss     : 12943.731915118244
# (validation) epoch 240, avg. validation loss: 10348.8681640625
# (train) epoch 241,      avg. train loss     : 12939.15567725929
# (validation) epoch 241, avg. validation loss: 10348.95703125
# (train) epoch 242,      avg. train loss     : 12934.829418285473
# (validation) epoch 242, avg. validation loss: 10348.888671875
# (train) epoch 243,      avg. train loss     : 12939.136927259291
# (validation) epoch 243, avg. validation loss: 10347.9755859375
# (train) epoch 244,      avg. train loss     : 12938.712674197635
# (validation) epoch 244, avg. validation loss: 10348.6953125
# (train) epoch 245,      avg. train loss     : 12945.390844066724
# (validation) epoch 245, avg. validation loss: 10348.767578125
# (train) epoch 246,      avg. train loss     : 12943.352533783784
# (validation) epoch 246, avg. validation loss: 10348.193359375
# (train) epoch 247,      avg. train loss     : 12945.441044657939
# (validation) epoch 247, avg. validation loss: 10347.994140625
# (train) epoch 248,      avg. train loss     : 12956.4447265625
# (validation) epoch 248, avg. validation loss: 10347.7939453125
# (train) epoch 249,      avg. train loss     : 12943.131677576013
# (validation) epoch 249, avg. validation loss: 10348.6357421875
# (train) epoch 250,      avg. train loss     : 12931.107775548986
# (validation) epoch 250, avg. validation loss: 10347.5810546875
# Entire training of palo-alto's model took 93.64656496047974 seconds.
# dumping
# dumped?

# %% [markdown]
# ## Inference on test sets

# %% [markdown]
# ## Create a DataLoader class for training

# %%
batch_sz = 4  # batch size 
fullcity_loader = DataLoader(city_dataset,batch_size=batch_sz)
print(f"{split.upper()} dataloader using batches of {batch_sz} is ready for city {city.upper()}.")
# Out:
# TRAIN dataloader using batches of 4 is ready for city PALO-ALTO.

# %% [markdown]
# ## Sample a batch of data and visualize

# %%
import matplotlib.pyplot as plt
import random


def show_sample_batch(sample_batch):
    """visualize the trajectory for a batch of samples"""
    inp, out = sample_batch
    print(f"    Shape is (batch, trajectory_length, coord_dim)")
    print(f"    inp shape = {inp.shape}")
    print(f"    out shape = {out.shape}")
    batch_sz = inp.size(0)
    agent_sz = inp.size(1) # Input trajectory length?
    print(f"    batch_sz = {batch_sz}")
    print(f"    agent_sz = {agent_sz}")
    
    fig, axs = plt.subplots(2,batch_sz, figsize=(15, 6), facecolor='w', edgecolor='k')
    fig.subplots_adjust(hspace = .5, wspace=.001)
#     axs = axs.ravel()   
    print("\nEach column is one (input,output) pair")
    axs[0][0].set_ylabel("First row")
    for i in range(batch_sz):
        # first two feature dimensions are (x,y) positions
        axs[0][i].scatter(inp[i,:,0], inp[i,:,1], c='lightskyblue')
        axs[1][i].scatter(out[i,:,0], out[i,:,1], c='lightcoral')
        # Show position at first time step
        axs[0][i].scatter(inp[i,0,0], inp[i,0,1], c='g')
        axs[1][i].scatter(out[i,0,0], out[i,0,1], c='g')        

        
for ith_batch, sample_batch in enumerate(fullcity_loader):
    print(f"Loaded batch #{ith_batch}")
    inp, out = sample_batch #
    """
    TODO:
      implement your Deep learning model
      implement training routine
    """
    show_sample_batch(sample_batch)
    break
# Out:
# Loaded batch #0
#     Shape is (batch, trajectory_length, coord_dim)
#     inp shape = torch.Size([4, 50, 2])
#     out shape = torch.Size([4, 60, 2])
#     batch_sz = 4
#     agent_sz = 50
#
# Each column is one (input,output) pair

# %% [markdown]
# ## Training Loop

# %%
# loss = nn.MSELoss()
# input = torch.arange(12,dtype=torch.float32).reshape((3,4))
# print(input)
# target = input + 2
# print(target)
# output = loss(input,target)
# print(output)

# Check for GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"device = {device}")
# !nvidia-smi -L
# Out:
# device = cuda
# GPU 0: GeForce GTX 1080 Ti (UUID: GPU-d6df5c12-bb16-7de9-a4ce-b011f33dc39f)

# %%
# '''
# Define model
mlp = nn.Sequential(nn.Flatten(1,2),
                    nn.Linear(100, 256),
                    nn.ReLU(),
                    nn.Linear(256,256),
                    nn.ReLU(),
                    nn.Linear(256,120),
                    nn.Unflatten(1,(60,2)))

mlp.cuda()

# Hyperparameters
lr = 0.0001
num_epochs = 100
opt = torch.optim.Adam(mlp.parameters(),lr=lr)
# opt = torch.optim.SGD(mlp.parameters(),lr=lr)
loss_func = nn.MSELoss(reduction='sum')

# Train/val split
city = 'palo-alto' 
split = 'train'
full_dataset  = ArgoverseDataset(city = city, split = split)
train_set, validation_set = torch.utils.data.random_split(full_dataset, [int(len(full_dataset)*5/6), len(full_dataset)-int(len(full_dataset)*5/6)])

# Dataloaders
batch_size = 16
train_loader = DataLoader(train_set, batch_size=batch_size,shuffle=True,drop_last=True,pin_memory=True)
validation_loader = DataLoader(validation_set, batch_size=batch_size,drop_last=True)
train_samples_per_epoch = len(train_loader) * batch_size # Number of batches times batch size
validation_samples_per_epoch = len(validation_loader) * batch_size
print(f"train_samples_per_epoch = {train_samples_per_epoch}")
print(f"validation_samples_per_epoch = {validation_samples_per_epoch}")

all_losses1 = []
all_losses2 = []
# '''

# lr = 0.0001
# num_epochs = 100
# opt = torch.optim.Adam(mlp.parameters(),lr=lr)


import time
# from math import sqrt
from tqdm import tqdm
start_time = time.time()

for epoch in range(num_epochs):
    epoch_start = time.time()
    # Epoch for train set
    mlp.train()
    train_loss = 0
    train_loss_alt = 0
    for i_batch, sample_batch in enumerate(tqdm(train_loader)):
        inp, out = sample_batch # Get input and output labels
        inp = inp.float()
        out = out.float()      
        inp, out = inp.cuda(), out.cuda()
#         print(f"inp.shape = {inp.shape}")
#         break
#         print(f"out shape = {out.shape}")
        
        # Forward pass
        out_hats = mlp(inp)
#         print(out_hats.shape)
        l_alt = ((mlp(inp) - out) ** 2).sum()
        l = loss_func(out_hats, out)     
        # Gradient descent
        opt.zero_grad()
        l.backward()
        opt.step()        
        train_loss += l.item()
        train_loss_alt += l_alt.item()
    all_losses1.append(train_loss / train_samples_per_epoch)  # Loss per training sample
        
    # Epoch for validation set
    mlp.eval()
    validation_loss = 0
    validation_loss_alt = 0
    for i_batch, sample_batch in enumerate(tqdm(validation_loader)):
        inp, out = sample_batch
        inp = inp.float()
        out = out.float()
        inp, out = inp.cuda(), out.cuda()
        # Forward pass
        l_alt = ((mlp(inp) - out) ** 2).sum()
        l = loss_func(mlp(inp), out)
        validation_loss += l.item()
        validation_loss_alt += l_alt.item()
    all_losses2.append(validation_loss / validation_samples_per_epoch) # Loss per validation sample
    
    # Print training progress
    print(f'(train) epoch {epoch + 1},      avg. train loss     : {train_loss / train_samples_per_epoch}')
    print(f'(validation) epoch {epoch + 1}, avg. validation loss: {validation_loss / validation_samples_per_epoch}')
    print(f"Epoch took {time.time()-epoch_start} seconds.\n")
    
end_time = time.time()
print(f"Entire training of {num_epochs} epochs took {end_time-start_time} seconds.")
# Out:
# train_samples_per_epoch = 9984
# validation_samples_per_epoch = 1984
# 100%|██████████| 624/624 [00:01<00:00, 384.12it/s]
# 100%|██████████| 124/124 [00:00<00:00, 980.93it/s]
# (train) epoch 1,      avg. train loss     : 22563257.841821916
# (validation) epoch 1, avg. validation loss: 212142.7338079637
# Epoch took 1.7576756477355957 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 404.86it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1035.03it/s]
# (train) epoch 2,      avg. train loss     : 196151.87615184294
# (validation) epoch 2, avg. validation loss: 183135.47328629033
# Epoch took 1.6670024394989014 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 370.29it/s]
# 100%|██████████| 124/124 [00:00<00:00, 876.53it/s]
# (train) epoch 3,      avg. train loss     : 187210.04482797475
# (validation) epoch 3, avg. validation loss: 192283.02627268145
# Epoch took 1.8325402736663818 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 390.77it/s]
# 100%|██████████| 124/124 [00:00<00:00, 989.75it/s]
# (train) epoch 4,      avg. train loss     : 182537.53923778044
# (validation) epoch 4, avg. validation loss: 198991.99351058467
# Epoch took 1.7287161350250244 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 388.80it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1057.28it/s]
# (train) epoch 5,      avg. train loss     : 179915.12454301884
# (validation) epoch 5, avg. validation loss: 173549.68781502015
# Epoch took 1.7290852069854736 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 392.32it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1127.74it/s]
# (train) epoch 6,      avg. train loss     : 174950.2217172476
# (validation) epoch 6, avg. validation loss: 186635.6154233871
# Epoch took 1.7060413360595703 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 370.42it/s]
# 100%|██████████| 124/124 [00:00<00:00, 875.17it/s]
# (train) epoch 7,      avg. train loss     : 167966.8411708734
# (validation) epoch 7, avg. validation loss: 154877.20362903227
# Epoch took 1.833294153213501 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 360.35it/s]
# 100%|██████████| 124/124 [00:00<00:00, 813.58it/s]
# (train) epoch 8,      avg. train loss     : 162525.69373497597
# (validation) epoch 8, avg. validation loss: 163048.0972152218
# Epoch took 1.889747142791748 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 330.33it/s]
# 100%|██████████| 124/124 [00:00<00:00, 864.59it/s]
# (train) epoch 9,      avg. train loss     : 156274.94474283853
# (validation) epoch 9, avg. validation loss: 129423.97649949597
# Epoch took 2.0388011932373047 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 385.59it/s]
# 100%|██████████| 124/124 [00:00<00:00, 993.64it/s]
# (train) epoch 10,      avg. train loss     : 142689.82205278447
# (validation) epoch 10, avg. validation loss: 132275.7326108871
# Epoch took 1.7497437000274658 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 437.60it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1024.95it/s]
# (train) epoch 11,      avg. train loss     : 136969.45216721756
# (validation) epoch 11, avg. validation loss: 130614.33833165323
# Epoch took 1.5538837909698486 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 436.42it/s]
# 100%|██████████| 124/124 [00:00<00:00, 999.46it/s]
# (train) epoch 12,      avg. train loss     : 128932.64715419672
# (validation) epoch 12, avg. validation loss: 112341.02633568548
# Epoch took 1.5583486557006836 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 441.08it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1046.11it/s]
# (train) epoch 13,      avg. train loss     : 116356.08823492588
# (validation) epoch 13, avg. validation loss: 151636.91588961694
# Epoch took 1.5388095378875732 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 424.64it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1052.34it/s]
# (train) epoch 14,      avg. train loss     : 110048.18751878005
# (validation) epoch 14, avg. validation loss: 96614.53118699597
# Epoch took 1.5928616523742676 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 427.70it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1012.06it/s]
# (train) epoch 15,      avg. train loss     : 99099.56931089744
# (validation) epoch 15, avg. validation loss: 98326.2404548891
# Epoch took 1.5872907638549805 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 395.98it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1041.85it/s]
# (train) epoch 16,      avg. train loss     : 88831.85002253606
# (validation) epoch 16, avg. validation loss: 107567.1521232359
# Epoch took 1.700190782546997 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 374.27it/s]
# 100%|██████████| 124/124 [00:00<00:00, 914.18it/s]
# (train) epoch 17,      avg. train loss     : 81999.61013559195
# (validation) epoch 17, avg. validation loss: 72603.93170362903
# Epoch took 1.8077833652496338 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 411.36it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1018.49it/s]
# (train) epoch 18,      avg. train loss     : 72617.63117550581
# (validation) epoch 18, avg. validation loss: 70084.35594128024
# Epoch took 1.6449651718139648 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 396.37it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1008.73it/s]
# (train) epoch 19,      avg. train loss     : 65498.813986753805
# (validation) epoch 19, avg. validation loss: 64568.36863659274
# Epoch took 1.7029297351837158 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 417.27it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1088.19it/s]
# (train) epoch 20,      avg. train loss     : 65697.36324055989
# (validation) epoch 20, avg. validation loss: 47318.36580141129
# Epoch took 1.613689661026001 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 393.00it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1018.50it/s]
# (train) epoch 21,      avg. train loss     : 56574.53052696815
# (validation) epoch 21, avg. validation loss: 45868.067839591735
# Epoch took 1.7152247428894043 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 367.46it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1052.82it/s]
# (train) epoch 22,      avg. train loss     : 52993.03586363181
# (validation) epoch 22, avg. validation loss: 44531.70544039818
# Epoch took 1.8219599723815918 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 392.95it/s]
# 100%|██████████| 124/124 [00:00<00:00, 985.83it/s]
# (train) epoch 23,      avg. train loss     : 48682.124896709734
# (validation) epoch 23, avg. validation loss: 47331.88610446068
# Epoch took 1.7197935581207275 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 332.11it/s]
# 100%|██████████| 124/124 [00:00<00:00, 793.02it/s]
# (train) epoch 24,      avg. train loss     : 48187.95402018229
# (validation) epoch 24, avg. validation loss: 43449.065949470765
# Epoch took 2.0407681465148926 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 372.64it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1081.21it/s]
# (train) epoch 25,      avg. train loss     : 44580.01122264373
# (validation) epoch 25, avg. validation loss: 37713.424899193546
# Epoch took 1.7976012229919434 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 391.51it/s]
# 100%|██████████| 124/124 [00:00<00:00, 891.77it/s]
# (train) epoch 26,      avg. train loss     : 42280.06524345202
# (validation) epoch 26, avg. validation loss: 31250.48172095514
# Epoch took 1.7388942241668701 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 400.43it/s]
# 100%|██████████| 124/124 [00:00<00:00, 984.90it/s]
# (train) epoch 27,      avg. train loss     : 43502.00667004708
# (validation) epoch 27, avg. validation loss: 33968.22330204133
# Epoch took 1.6900289058685303 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 360.97it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1008.73it/s]
# (train) epoch 28,      avg. train loss     : 34886.45353190104
# (validation) epoch 28, avg. validation loss: 34170.745109311996
# Epoch took 1.8577427864074707 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 369.45it/s]
# 100%|██████████| 124/124 [00:00<00:00, 820.42it/s]
# (train) epoch 29,      avg. train loss     : 34159.39513377654
# (validation) epoch 29, avg. validation loss: 32182.959740423386
# Epoch took 1.8482098579406738 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 353.14it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1084.22it/s]
# (train) epoch 30,      avg. train loss     : 37542.506727952226
# (validation) epoch 30, avg. validation loss: 31989.065689579133
# Epoch took 1.8877918720245361 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 366.60it/s]
# 100%|██████████| 124/124 [00:00<00:00, 877.53it/s]
# (train) epoch 31,      avg. train loss     : 39851.98303222656
# (validation) epoch 31, avg. validation loss: 34440.909762474796
# Epoch took 1.8514049053192139 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 407.47it/s]
# 100%|██████████| 124/124 [00:00<00:00, 995.91it/s]
# (train) epoch 32,      avg. train loss     : 34826.70025165264
# (validation) epoch 32, avg. validation loss: 21468.677718623992
# Epoch took 1.6619594097137451 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 379.99it/s]
# 100%|██████████| 124/124 [00:00<00:00, 902.66it/s]
# (train) epoch 33,      avg. train loss     : 34036.09255120693
# (validation) epoch 33, avg. validation loss: 31610.979051159273
# Epoch took 1.7842278480529785 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 384.53it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1093.69it/s]
# (train) epoch 34,      avg. train loss     : 34889.45376821665
# (validation) epoch 34, avg. validation loss: 21732.562216481856
# Epoch took 1.741459608078003 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 357.90it/s]
# 100%|██████████| 124/124 [00:00<00:00, 864.58it/s]
# (train) epoch 35,      avg. train loss     : 32481.574037209535
# (validation) epoch 35, avg. validation loss: 31726.91146358367
# Epoch took 1.893223524093628 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 384.26it/s]
# 100%|██████████| 124/124 [00:00<00:00, 981.26it/s]
# (train) epoch 36,      avg. train loss     : 29446.941830366086
# (validation) epoch 36, avg. validation loss: 36842.40832913307
# Epoch took 1.7564818859100342 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 464.25it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1013.51it/s]
# (train) epoch 37,      avg. train loss     : 35396.50450564653
# (validation) epoch 37, avg. validation loss: 45332.03154926915
# Epoch took 1.4723258018493652 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 456.62it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1038.98it/s]
# (train) epoch 38,      avg. train loss     : 29197.697994134363
# (validation) epoch 38, avg. validation loss: 31915.14322391633
# Epoch took 1.4918653964996338 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 424.97it/s]
# 100%|██████████| 124/124 [00:00<00:00, 977.50it/s]
# (train) epoch 39,      avg. train loss     : 33250.95568065154
# (validation) epoch 39, avg. validation loss: 25168.11591166835
# Epoch took 1.6017365455627441 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 409.98it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1052.33it/s]
# (train) epoch 40,      avg. train loss     : 30377.598305726664
# (validation) epoch 40, avg. validation loss: 23118.766184160788
# Epoch took 1.6469435691833496 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 385.48it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1001.73it/s]
# (train) epoch 41,      avg. train loss     : 29315.426720252402
# (validation) epoch 41, avg. validation loss: 29590.750244140625
# Epoch took 1.7481744289398193 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 377.32it/s]
# 100%|██████████| 124/124 [00:00<00:00, 902.43it/s]
# (train) epoch 42,      avg. train loss     : 31682.413666553988
# (validation) epoch 42, avg. validation loss: 27913.030328566027
# Epoch took 1.7966585159301758 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 381.47it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1039.29it/s]
# (train) epoch 43,      avg. train loss     : 32485.00578425481
# (validation) epoch 43, avg. validation loss: 26103.577431955644
# Epoch took 1.7613956928253174 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 345.71it/s]
# 100%|██████████| 124/124 [00:00<00:00, 892.51it/s]
# (train) epoch 44,      avg. train loss     : 26562.999389648438
# (validation) epoch 44, avg. validation loss: 27248.622330204133
# Epoch took 1.9489483833312988 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 406.01it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1046.58it/s]
# (train) epoch 45,      avg. train loss     : 30415.758415026543
# (validation) epoch 45, avg. validation loss: 24895.170181766633
# Epoch took 1.6610171794891357 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 417.74it/s]
# 100%|██████████| 124/124 [00:00<00:00, 897.75it/s]
# (train) epoch 46,      avg. train loss     : 34022.39085036058
# (validation) epoch 46, avg. validation loss: 24556.159951486894
# Epoch took 1.6374413967132568 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 371.66it/s]
# 100%|██████████| 124/124 [00:00<00:00, 989.70it/s]
# (train) epoch 47,      avg. train loss     : 29839.682966183394
# (validation) epoch 47, avg. validation loss: 22266.431065713205
# Epoch took 1.8095016479492188 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 385.20it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1045.40it/s]
# (train) epoch 48,      avg. train loss     : 27473.06285603841
# (validation) epoch 48, avg. validation loss: 24273.45498361895
# Epoch took 1.7439525127410889 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 363.62it/s]
# 100%|██████████| 124/124 [00:00<00:00, 893.20it/s]
# (train) epoch 49,      avg. train loss     : 27648.84297610552
# (validation) epoch 49, avg. validation loss: 28819.308822139617
# Epoch took 1.8606274127960205 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 375.26it/s]
# 100%|██████████| 124/124 [00:00<00:00, 996.21it/s]
# (train) epoch 50,      avg. train loss     : 30252.409267327723
# (validation) epoch 50, avg. validation loss: 19712.306813886087
# Epoch took 1.7929935455322266 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 411.96it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1034.07it/s]
# (train) epoch 51,      avg. train loss     : 26432.41753524389
# (validation) epoch 51, avg. validation loss: 34825.33794575353
# Epoch took 1.640906810760498 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 374.04it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1068.58it/s]
# (train) epoch 52,      avg. train loss     : 27100.662635216348
# (validation) epoch 52, avg. validation loss: 17309.550946635583
# Epoch took 1.7898285388946533 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 333.98it/s]
# 100%|██████████| 124/124 [00:00<00:00, 948.40it/s]
# (train) epoch 53,      avg. train loss     : 30005.500694079277
# (validation) epoch 53, avg. validation loss: 19276.85300371724
# Epoch took 2.004542827606201 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 403.18it/s]
# 100%|██████████| 124/124 [00:00<00:00, 921.26it/s]
# (train) epoch 54,      avg. train loss     : 27515.725322234324
# (validation) epoch 54, avg. validation loss: 19658.285140498992
# Epoch took 1.6880772113800049 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 416.18it/s]
# 100%|██████████| 124/124 [00:00<00:00, 864.94it/s]
# (train) epoch 55,      avg. train loss     : 25672.092119265824
# (validation) epoch 55, avg. validation loss: 22867.04287424395
# Epoch took 1.649165153503418 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 353.23it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1023.31it/s]
# (train) epoch 56,      avg. train loss     : 27887.1387892503
# (validation) epoch 56, avg. validation loss: 30028.38697076613
# Epoch took 1.8934690952301025 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 364.01it/s]
# 100%|██████████| 124/124 [00:00<00:00, 876.04it/s]
# (train) epoch 57,      avg. train loss     : 30605.842980018027
# (validation) epoch 57, avg. validation loss: 30470.19189453125
# Epoch took 1.8617653846740723 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 333.34it/s]
# 100%|██████████| 124/124 [00:00<00:00, 838.47it/s]
# (train) epoch 58,      avg. train loss     : 26622.59073423728
# (validation) epoch 58, avg. validation loss: 22094.830621534777
# Epoch took 2.024770498275757 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 359.00it/s]
# 100%|██████████| 124/124 [00:00<00:00, 894.26it/s]
# (train) epoch 59,      avg. train loss     : 26097.684244791668
# (validation) epoch 59, avg. validation loss: 21606.751905871977
# Epoch took 1.881462574005127 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 361.02it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1064.16it/s]
# (train) epoch 60,      avg. train loss     : 27940.593005058094
# (validation) epoch 60, avg. validation loss: 57446.37770917339
# Epoch took 1.8510093688964844 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 388.49it/s]
# 100%|██████████| 124/124 [00:00<00:00, 941.41it/s]
# (train) epoch 61,      avg. train loss     : 26461.397645607973
# (validation) epoch 61, avg. validation loss: 20125.812570879538
# Epoch took 1.7440600395202637 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 370.08it/s]
# 100%|██████████| 124/124 [00:00<00:00, 815.55it/s]
# (train) epoch 62,      avg. train loss     : 29252.479028163812
# (validation) epoch 62, avg. validation loss: 31878.106965095765
# Epoch took 1.8440611362457275 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 375.73it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1006.39it/s]
# (train) epoch 63,      avg. train loss     : 26742.057425474508
# (validation) epoch 63, avg. validation loss: 31429.3550749748
# Epoch took 1.7886676788330078 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 408.65it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1009.54it/s]
# (train) epoch 64,      avg. train loss     : 29915.31334431966
# (validation) epoch 64, avg. validation loss: 27189.535093245966
# Epoch took 1.6561059951782227 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 431.55it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1041.84it/s]
# (train) epoch 65,      avg. train loss     : 25488.377591646633
# (validation) epoch 65, avg. validation loss: 29254.407431325606
# Epoch took 1.5708582401275635 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 394.87it/s]
# 100%|██████████| 124/124 [00:00<00:00, 978.03it/s]
# (train) epoch 66,      avg. train loss     : 27400.52595402644
# (validation) epoch 66, avg. validation loss: 22543.54229145665
# Epoch took 1.7128753662109375 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 391.77it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1085.97it/s]
# (train) epoch 67,      avg. train loss     : 24267.055490347055
# (validation) epoch 67, avg. validation loss: 19605.696580456148
# Epoch took 1.7124605178833008 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 426.11it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1036.07it/s]
# (train) epoch 68,      avg. train loss     : 27461.410082694812
# (validation) epoch 68, avg. validation loss: 23411.414558656754
# Epoch took 1.5908050537109375 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 414.24it/s]
# 100%|██████████| 124/124 [00:00<00:00, 892.91it/s]
# (train) epoch 69,      avg. train loss     : 25281.669422638723
# (validation) epoch 69, avg. validation loss: 18905.09704983619
# Epoch took 1.6525328159332275 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 349.37it/s]
# 100%|██████████| 124/124 [00:00<00:00, 900.12it/s]
# (train) epoch 70,      avg. train loss     : 23491.442404722555
# (validation) epoch 70, avg. validation loss: 38799.69047694052
# Epoch took 1.9306414127349854 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 351.52it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1025.38it/s]
# (train) epoch 71,      avg. train loss     : 27091.45269931891
# (validation) epoch 71, avg. validation loss: 20673.013585244455
# Epoch took 1.9025404453277588 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 390.30it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1058.43it/s]
# (train) epoch 72,      avg. train loss     : 27730.15580162635
# (validation) epoch 72, avg. validation loss: 25447.664133379538
# Epoch took 1.72068190574646 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 359.88it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1030.85it/s]
# (train) epoch 73,      avg. train loss     : 28029.544752854566
# (validation) epoch 73, avg. validation loss: 20042.445068359375
# Epoch took 1.8583543300628662 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 383.08it/s]
# 100%|██████████| 124/124 [00:00<00:00, 816.01it/s]
# (train) epoch 74,      avg. train loss     : 25767.555341671676
# (validation) epoch 74, avg. validation loss: 48947.74322706653
# Epoch took 1.7862954139709473 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 374.51it/s]
# 100%|██████████| 124/124 [00:00<00:00, 919.24it/s]
# (train) epoch 75,      avg. train loss     : 28179.284303322816
# (validation) epoch 75, avg. validation loss: 22805.832740045364
# Epoch took 1.8067312240600586 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 389.69it/s]
# 100%|██████████| 124/124 [00:00<00:00, 910.57it/s]
# (train) epoch 76,      avg. train loss     : 28120.57677831405
# (validation) epoch 76, avg. validation loss: 19713.592300907258
# Epoch took 1.7432479858398438 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 376.07it/s]
# 100%|██████████| 124/124 [00:00<00:00, 924.08it/s]
# (train) epoch 77,      avg. train loss     : 23644.97646077474
# (validation) epoch 77, avg. validation loss: 25824.49560546875
# Epoch took 1.7991254329681396 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 427.15it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1029.93it/s]
# (train) epoch 78,      avg. train loss     : 29125.945782001203
# (validation) epoch 78, avg. validation loss: 24493.725963961693
# Epoch took 1.5871849060058594 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 334.85it/s]
# 100%|██████████| 124/124 [00:00<00:00, 874.84it/s]
# (train) epoch 79,      avg. train loss     : 25499.81029412685
# (validation) epoch 79, avg. validation loss: 27577.2982453377
# Epoch took 2.011225461959839 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 385.66it/s]
# 100%|██████████| 124/124 [00:00<00:00, 902.85it/s]
# (train) epoch 80,      avg. train loss     : 24736.090377416367
# (validation) epoch 80, avg. validation loss: 23776.37105437248
# Epoch took 1.7614567279815674 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 333.74it/s]
# 100%|██████████| 124/124 [00:00<00:00, 788.19it/s]
# (train) epoch 81,      avg. train loss     : 24483.943202092098
# (validation) epoch 81, avg. validation loss: 22798.14553143901
# Epoch took 2.0330970287323 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 340.75it/s]
# 100%|██████████| 124/124 [00:00<00:00, 998.14it/s]
# (train) epoch 82,      avg. train loss     : 25683.5605860001
# (validation) epoch 82, avg. validation loss: 19275.521429246473
# Epoch took 1.9620640277862549 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 364.85it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1012.10it/s]
# (train) epoch 83,      avg. train loss     : 24555.854642427883
# (validation) epoch 83, avg. validation loss: 22229.607319493447
# Epoch took 1.8394768238067627 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 357.60it/s]
# 100%|██████████| 124/124 [00:00<00:00, 946.45it/s]
# (train) epoch 84,      avg. train loss     : 27223.627360808543
# (validation) epoch 84, avg. validation loss: 22821.537156628023
# Epoch took 1.8812520503997803 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 397.85it/s]
# 100%|██████████| 124/124 [00:00<00:00, 955.36it/s]
# (train) epoch 85,      avg. train loss     : 23320.46907786834
# (validation) epoch 85, avg. validation loss: 25074.274634576614
# Epoch took 1.704280138015747 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 409.19it/s]
# 100%|██████████| 124/124 [00:00<00:00, 990.32it/s]
# (train) epoch 86,      avg. train loss     : 25633.815773988383
# (validation) epoch 86, avg. validation loss: 23826.844868321572
# Epoch took 1.6569328308105469 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 402.11it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1040.24it/s]
# (train) epoch 87,      avg. train loss     : 25672.688553247695
# (validation) epoch 87, avg. validation loss: 24438.9779328377
# Epoch took 1.6772902011871338 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 403.68it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1009.95it/s]
# (train) epoch 88,      avg. train loss     : 24494.36748485076
# (validation) epoch 88, avg. validation loss: 23940.389703566027
# Epoch took 1.6741516590118408 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 416.36it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1018.86it/s]
# (train) epoch 89,      avg. train loss     : 24393.85493351863
# (validation) epoch 89, avg. validation loss: 20482.03988155242
# Epoch took 1.6258361339569092 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 406.26it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1013.55it/s]
# (train) epoch 90,      avg. train loss     : 24169.083579821465
# (validation) epoch 90, avg. validation loss: 22941.80994046119
# Epoch took 1.6640441417694092 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 384.31it/s]
# 100%|██████████| 124/124 [00:00<00:00, 924.20it/s]
# (train) epoch 91,      avg. train loss     : 23618.014845628004
# (validation) epoch 91, avg. validation loss: 21594.815043787803
# Epoch took 1.7641746997833252 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 412.73it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1032.21it/s]
# (train) epoch 92,      avg. train loss     : 25376.556229028945
# (validation) epoch 92, avg. validation loss: 35787.121928553424
# Epoch took 1.6386618614196777 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 399.74it/s]
# 100%|██████████| 124/124 [00:00<00:00, 998.91it/s]
# (train) epoch 93,      avg. train loss     : 24176.07290258163
# (validation) epoch 93, avg. validation loss: 18197.313098538307
# Epoch took 1.6904847621917725 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 417.14it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1050.62it/s]
# (train) epoch 94,      avg. train loss     : 26968.359776423527
# (validation) epoch 94, avg. validation loss: 24689.460378339212
# Epoch took 1.6201627254486084 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 415.92it/s]
# 100%|██████████| 124/124 [00:00<00:00, 855.96it/s]
# (train) epoch 95,      avg. train loss     : 27145.33490537986
# (validation) epoch 95, avg. validation loss: 25109.404934790826
# Epoch took 1.6507501602172852 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 372.61it/s]
# 100%|██████████| 124/124 [00:00<00:00, 888.70it/s]
# (train) epoch 96,      avg. train loss     : 23682.61655836839
# (validation) epoch 96, avg. validation loss: 21593.075463079636
# Epoch took 1.8211312294006348 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 407.76it/s]
# 100%|██████████| 124/124 [00:00<00:00, 914.22it/s]
# (train) epoch 97,      avg. train loss     : 25933.365533290766
# (validation) epoch 97, avg. validation loss: 20456.36472246724
# Epoch took 1.671588659286499 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 445.65it/s]
# 100%|██████████| 124/124 [00:00<00:00, 1062.19it/s]
# (train) epoch 98,      avg. train loss     : 25431.819559733074
# (validation) epoch 98, avg. validation loss: 20045.204479586693
# Epoch took 1.5225775241851807 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 415.15it/s]
# 100%|██████████| 124/124 [00:00<00:00, 837.12it/s]
# (train) epoch 99,      avg. train loss     : 24176.79426613832
# (validation) epoch 99, avg. validation loss: 16408.993097120714
# Epoch took 1.65696120262146 seconds.
# 100%|██████████| 624/624 [00:01<00:00, 410.04it/s]
# 100%|██████████| 124/124 [00:00<00:00, 830.42it/s]
# (train) epoch 100,      avg. train loss     : 24101.31012823643
# (validation) epoch 100, avg. validation loss: 21270.051072643648
# Epoch took 1.6773581504821777 seconds.
#
# Entire training of 100 epochs took 174.9170696735382 seconds.

# %%
# 400 epochs at lr=0.00001 [done]

# ~100 epochs at lr=0.0001

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# Should be per trajectory loss
plt.figure()
ax = plt.gca()
ax.set_ylim([0,500000])
plt.plot(all_losses1,label="avg. train loss")

# plt.plot(all_losses2,label="avg. validation loss")
leg = plt.legend(loc='upper center')
plt.show()

# %%
# Inference on test

split = 'test'
counter = 0
currCity = 0
test_input, test_output = get_all_trajectories(split="test", normalized=False)
#We can't use a dataset or a dataloader because they don't work for the test set (something to do with the fact that the test set doesn't have outputs)

with open('predictions.txt', 'w') as f:
    print("hello",file=f, flush=True)
    for i_batch, curr_input in enumerate(test_input):
        #curr_input is a numpy array, so first we need to turn it into a tensor, then add an extra dimension around it, then make it a float tensor instead of a double tensor
        predict = mlps[currCity](torch.from_numpy(curr_input).unsqueeze(0).float())

        print("" + str(counter) + "_" + str(cities[currCity]),end='',file=f)
        for coor in predict[0]:
            print("," + str(coor[0].item()) + "," + str(coor[1].item()),end='',file=f)
        print(file=f, flush=True)
        counter = counter+1
        if counter >= test_lengths[currCity]:
            counter = 0
            currCity = currCity+1

    f.close()
